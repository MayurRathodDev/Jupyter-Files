# %%
import pandas as pd
import numpy as np
from rapidfuzz import process, fuzz
import re
from tqdm import tqdm
from typing import Optional, Any, List, Tuple, Dict

# %% [markdown]
# ### High Request volume targetted keywords having less than 20 RR%

# %%
# Keywords request response
requests_df = pd.read_csv("395539_keywordRR_12-18July24.csv")
requests_df.shape
# Out:
# (413147, 6)

# %%
requests_df.head()
# Out:
#   trimmed_keyword     keywords  word_cnt  request  response         RR  \
# 0            milk         milk         1    21312     19751  92.675488
# 1            eggs         eggs         1    20600     19974  96.961165
# 2           water        water         1    13566     13219  97.442135
# 3      groundbeef  ground beef         2    12707         3   0.023609
# 4           bread        bread         1    12228     11666  95.403991
#
#   lower_search_keyword
# 0                 milk
# 1                 eggs
# 2                water
# 3          ground beef
# 4                bread

# %%
requests_df[requests_df['keywords']=='dark chocolate'].value_counts()
# Out:
# trimmed_keyword  keywords        word_cnt  request  response  RR         lower_search_keyword
# darkchocolate    dark chocolate  2         590      60        10.169492  dark chocolate          1
# dtype: int64

# %%
requests_df.columns
# Out:
# Index(['trimmed_keyword', 'keywords', 'word_cnt', 'request', 'response', 'RR'], dtype='object')

# %%
# Keyword campaign level data
campaign_keywords = pd.read_csv("Wakefern_keywords_in_campaign_19thJuly.tsv000", sep='\t')
campaign_keywords.shape
# Out:
# (20526, 10)

# %%
campaign_keywords.head()
# Out:
#    marketplace_client_id  client_id  marketing_campaign_id  \
# 0                 395539   10043595                 776063
# 1                 395539   10046486                 785999
# 2                 395539   10043810                 773748
# 3                 395539   10043820                 773755
# 4                 395539   10042466                 775235
#
#                               text is_negative match_type status_type  \
# 0            salad dressing maries           t      EXACT      PAUSED
# 1  almond milk unsweetened vanilla           f     PHRASE      ACTIVE
# 2                   kleenex tissue           t     PHRASE      ACTIVE
# 3                          charmin           t     PHRASE      ACTIVE
# 4                        bel veeda           t      EXACT      ACTIVE
#
#    bidding_value bidding_currency  bidding_value_usd
# 0            NaN              NaN                NaN
# 1            1.0              USD                1.0
# 2            NaN              NaN                NaN
# 3            NaN              NaN                NaN
# 4            NaN              NaN                NaN

# %%
len(campaign_keywords['text'].unique())
# Out:
# 10370

# %%
campaign_keywords[campaign_keywords['marketing_campaign_id']==847661]
# Out:
#        marketplace_client_id  client_id  marketing_campaign_id  \
# 4511                  395539   10043598                 847661
# 5990                  395539   10043598                 847661
# 6279                  395539   10043598                 847661
# 8512                  395539   10043598                 847661
# 9748                  395539   10043598                 847661
# 10066                 395539   10043598                 847661
# 11585                 395539   10043598                 847661
# 12982                 395539   10043598                 847661
# 12983                 395539   10043598                 847661
# 15128                 395539   10043598                 847661
# 17623                 395539   10043598                 847661
# 17838                 395539   10043598                 847661
# 19184                 395539   10043598                 847661
# 19869                 395539   10043598                 847661
# 19870                 395539   10043598                 847661
# 20477                 395539   10043598                 847661
#
#                        text is_negative match_type status_type  bidding_value  \
# 4511              zip locks           f      EXACT      ACTIVE            1.0
# 5990        90 count ziploc           f      EXACT      ACTIVE            0.7
# 6279           90 ct ziploc           f      EXACT      ACTIVE            0.7
# 8512   90 count ziplock bag           f      EXACT      ACTIVE            0.7
# 9748               siplocks           f      EXACT      ACTIVE            0.7
# 10066      90 count ziplock           f      EXACT      ACTIVE            0.7
# 11585           ziploc bags           f      EXACT      ACTIVE            0.7
# 12982               siplocs           f      EXACT      ACTIVE            0.7
# 12983               siplock           f      EXACT      ACTIVE            0.7
# 15128               ziplocs           f      EXACT      ACTIVE            0.7
# 17623                siploc           f      EXACT      ACTIVE            0.7
# 17838  90 count ziploc bags           f      EXACT      ACTIVE            0.7
# 19184                ziploc           f      EXACT      ACTIVE            1.0
# 19869            ziploc bag           f      EXACT      ACTIVE            1.0
# 19870   ziploc freezer bags           f      EXACT      ACTIVE            1.0
# 20477               ziplock           f      EXACT      ACTIVE            1.0
#
#       bidding_currency  bidding_value_usd
# 4511               USD                1.0
# 5990               USD                0.7
# 6279               USD                0.7
# 8512               USD                0.7
# 9748               USD                0.7
# 10066              USD                0.7
# 11585              USD                0.7
# 12982              USD                0.7
# 12983              USD                0.7
# 15128              USD                0.7
# 17623              USD                0.7
# 17838              USD                0.7
# 19184              USD                1.0
# 19869              USD                1.0
# 19870              USD                1.0
# 20477              USD                1.0

# %%
# Filtering the Data

# Step 1: Filter the data where is_negative is 'f'
filtered_df = campaign_keywords[campaign_keywords['is_negative'] == 'f']

# Step 2: Filter the data where status_type is 'ACTIVE'
filtered_df = filtered_df[filtered_df['status_type'] == 'ACTIVE']

# Step 2: Group by 'marketing_campaign_id' and 'text'
grouped_df = filtered_df.groupby(['marketing_campaign_id', 'text'], as_index=False).first()

# Step 3: Drop duplicate combinations (this is automatically handled by the groupby and first combination)
cleaned_camp_df = grouped_df.drop_duplicates(subset=['marketing_campaign_id', 'text'])

# %%
cleaned_camp_df.head()
# Out:
#    marketing_campaign_id                    text  marketplace_client_id  \
# 0                 771022  all natural lunch meat                 395539
# 1                 771022             charcuterie                 395539
# 2                 771022                cold cut                 395539
# 3                 771022         cold cut turkey                 395539
# 4                 771022               cold cuts                 395539
#
#    client_id is_negative match_type status_type  bidding_value  \
# 0   10040730           f      EXACT      ACTIVE           0.61
# 1   10040730           f      EXACT      ACTIVE           0.61
# 2   10040730           f     PHRASE      ACTIVE           0.79
# 3   10040730           f      EXACT      ACTIVE           0.61
# 4   10040730           f      EXACT      ACTIVE           0.82
#
#   bidding_currency  bidding_value_usd
# 0              USD               0.61
# 1              USD               0.61
# 2              USD               0.79
# 3              USD               0.61
# 4              USD               0.82

# %%
cleaned_camp_df.shape
# Out:
# (9374, 10)

# %%
targetted_keywords = pd.merge(cleaned_camp_df[['marketing_campaign_id', 'text']], requests_df[['keywords', 'request', 'response', 'RR']], left_on='text', right_on='keywords', how='left')
targetted_keywords = targetted_keywords.drop('keywords', axis=1)
targetted_keywords.shape
# Out:
# (9412, 5)

# %%
targetted_keywords.head()
# Out:
#    marketing_campaign_id                    text  request  response         RR
# 0                 771022  all natural lunch meat      NaN       NaN        NaN
# 1                 771022             charcuterie    365.0     310.0  84.931507
# 2                 771022                cold cut     44.0      33.0  75.000000
# 3                 771022         cold cut turkey      9.0       6.0  66.666667
# 4                 771022               cold cuts    585.0     525.0  89.743590

# %%
len(targetted_keywords['text'].unique()) # 638, 563
# Out:
# 7334

# %%
len(cleaned_camp_df['text'].unique()) # 638, 563
# Out:
# 7334

# %%
targetted_keywords.head()
# Out:
#    marketing_campaign_id                    text  request  response         RR
# 0                 771022  all natural lunch meat      NaN       NaN        NaN
# 1                 771022             charcuterie    365.0     310.0  84.931507
# 2                 771022                cold cut     44.0      33.0  75.000000
# 3                 771022         cold cut turkey      9.0       6.0  66.666667
# 4                 771022               cold cuts    585.0     525.0  89.743590

# %%
targetted_keywords.isnull().sum()
# Out:
# marketing_campaign_id       0
# text                        0
# request                  4286
# response                 4286
# RR                       4286
# dtype: int64

# %%
targetted_keywords = targetted_keywords.fillna(0)

# %%
# High request volume targetted keywords
filtered_targetted_keywords = targetted_keywords[(targetted_keywords['request'] > 10) & (targetted_keywords['RR'] < 20)]
filtered_targetted_keywords.shape
# Out:
# (681, 5)

# %%
len(filtered_targetted_keywords['text'].unique())
# Out:
# 495

# %%
# len(targetted_keywords[(targetted_keywords['RR'] < 40) & (targetted_keywords['request'] > 10)])

# %%
filtered_targetted_keywords['request'].sum()    # RR<30: 180371.0, <20:167226.0 total:4027894
# Out:
# 257617.0

# %%
# filtered_targetted_keywords.to_csv("wakefern_targetted_consied_22ndJuly.csv", index=False)

# %%
# Fetch the list of marketing campaign ids
filtered_targetted_keywords['marketing_campaign_id'].unique()
# Out:
# array([771022, 771053, 771066, 771072, 771075, 771099, 771103, 771106,
#        771108, 771120, 771124, 771129, 771131, 771139, 771141, 772087,
#        772127, 773200, 773709, 773743, 773745, 773752, 773755, 773765,
#        773767, 774212, 774221, 774228, 774236, 774680, 774681, 775216,
#        775226, 775230, 775232, 775235, 775236, 775238, 775240, 775241,
#        775243, 775244, 775246, 775249, 776063, 776590, 779636, 779639,
#        779640, 779645, 779646, 779653, 779656, 779659, 779661, 779664,
#        780120, 780202, 780223, 780239, 780240, 782726, 782744, 785844,
#        785850, 785896, 785898, 785913, 785978, 785982, 785999, 786015,
#        786508, 786532, 787317, 792854, 792857, 792873, 792874, 800112,
#        800457, 805984, 811991, 817309, 817317, 818893, 818908, 819879,
#        820477, 821392, 821399, 821403, 821404, 821476, 822668, 822724,
#        830891, 830892, 830895, 830896, 835923, 837782, 847653, 847654,
#        847656, 847657, 847659, 847661, 847672, 850970, 852165, 852175,
#        852197, 852922, 852924, 852927, 852929, 852931, 852932, 852933,
#        852956, 859662, 861323, 863632, 863641, 863643, 863651, 863654,
#        863659, 863673, 863677], dtype=int64)

# %% [markdown]
# ### Campaign-Category Mapping

# %%
camp_category = pd.read_csv("wakefern_campaign_SKUs_category_20thJuly.tsv000", sep='\t')
camp_category.shape
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_16252\1853840350.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   camp_category = pd.read_csv("wakefern_campaign_SKUs_category_20thJuly.tsv000", sep='\t')
# (433743, 14)

# %%
camp_category.head()
# Out:
#    marketplace_client_id        merchant_id  marketing_campaign_id  \
# 0                 395539  P&G Personal Care                 852933
# 1                 395539  P&G Personal Care                 852933
# 2                 395539  P&G Personal Care                 852933
# 3                 395539  P&G Personal Care                 852933
# 4                 395539  P&G Personal Care                 852933
#
#    campaign_id                           sku_id category_l1    category_l2  \
# 0       604710  00812154036923___523___Shoprite     Grocery  Personal Care
# 1       604710  00037000800910___466___Shoprite     Grocery  Personal Care
# 2       604710  00047400528079___215___Shoprite     Grocery  Personal Care
# 3       604710  00012044056615___122___Shoprite     Grocery  Personal Care
# 4       604710  00012044037591___604___Shoprite     Grocery  Personal Care
#
#    category_l3                   category_l4          category_l5 category_l6  \
# 0  Bath & Body           Body Washes & Foams                  NaN         NaN
# 1    Deodorant             Women's Deodorant                  NaN         NaN
# 2      Shaving  Women's Shave & Hair Removal  Shave Creams & Gels         NaN
# 3    Deodorant               Men's Deodorant                  NaN         NaN
# 4    Deodorant               Men's Deodorant                  NaN         NaN
#
#    category_l7  category_l8                                             e_name
# 0          NaN          NaN        Native Sea Salt & Cedar Body Wash, 36 fl oz
# 1          NaN          NaN  Secret Aluminum Free Real Coconut 48 Hr Deodor...
# 2          NaN          NaN  Gillette Satin Care Sensitive Skin Shave Gel f...
# 3          NaN          NaN  Old Spice High Endurance Pure Sport Antiperspi...
# 4          NaN          NaN  Old Spice Men's Deodorant Aluminum-Free Fiji w...

# %%
# marketing_df = pd.read_csv("picknpay_mark&os_campaign_ids_16thJuly.tsv000", sep='\t')
# marketing_df.rename(columns={
#     'marketing_campaign_id': 'marketing_campaign_id',
#     'campaign_id': 'os_campaign_id',
#     'client_id': 'client_id'
# }, inplace=True)

# marketing_df.head()

# %%
# camp_category_grouped = pd.merge(camp_category, marketing_df[['marketing_campaign_id', 'os_campaign_id']], left_on='campaign_id', right_on='os_campaign_id', how='left')
# camp_category_grouped = camp_category_grouped.drop('os_campaign_id', axis=1)
# camp_category_grouped.head()

# %%
#Concatination
camp_category["concat"] = camp_category[['category_l1', 'category_l2', 'category_l3', 'category_l4', 'category_l5', 'category_l6',
       'category_l7', 'category_l8']].apply(lambda row: '>'.join([str(x).strip().lower() for x in row]), axis=1)
camp_category.head()
# Out:
#    marketplace_client_id        merchant_id  marketing_campaign_id  \
# 0                 395539  P&G Personal Care                 852933
# 1                 395539  P&G Personal Care                 852933
# 2                 395539  P&G Personal Care                 852933
# 3                 395539  P&G Personal Care                 852933
# 4                 395539  P&G Personal Care                 852933
#
#    campaign_id                           sku_id category_l1    category_l2  \
# 0       604710  00812154036923___523___Shoprite     Grocery  Personal Care
# 1       604710  00037000800910___466___Shoprite     Grocery  Personal Care
# 2       604710  00047400528079___215___Shoprite     Grocery  Personal Care
# 3       604710  00012044056615___122___Shoprite     Grocery  Personal Care
# 4       604710  00012044037591___604___Shoprite     Grocery  Personal Care
#
#    category_l3                   category_l4          category_l5 category_l6  \
# 0  Bath & Body           Body Washes & Foams                  NaN         NaN
# 1    Deodorant             Women's Deodorant                  NaN         NaN
# 2      Shaving  Women's Shave & Hair Removal  Shave Creams & Gels         NaN
# 3    Deodorant               Men's Deodorant                  NaN         NaN
# 4    Deodorant               Men's Deodorant                  NaN         NaN
#
#    category_l7  category_l8  \
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#
#                                               e_name  \
# 0        Native Sea Salt & Cedar Body Wash, 36 fl oz
# 1  Secret Aluminum Free Real Coconut 48 Hr Deodor...
# 2  Gillette Satin Care Sensitive Skin Shave Gel f...
# 3  Old Spice High Endurance Pure Sport Antiperspi...
# 4  Old Spice Men's Deodorant Aluminum-Free Fiji w...
#
#                                               concat
# 0  grocery>personal care>bath & body>body washes ...
# 1  grocery>personal care>deodorant>women's deodor...
# 2  grocery>personal care>shaving>women's shave & ...
# 3  grocery>personal care>deodorant>men's deodoran...
# 4  grocery>personal care>deodorant>men's deodoran...

# %%
# Step 2: Group by 'marketing_campaign_id' and 'text'
camp_category_df = camp_category.groupby(['marketing_campaign_id', 'concat'], as_index=False).first()

# # Step 3: Drop duplicate combinations (this is automatically handled by the groupby and first combination)
# camp_category_df = camp_category_df.drop_duplicates(subset=['marketing_campaign_id', 'concat'])
camp_category_df.shape
# Out:
# (351, 15)

# %%
camp_category_df = camp_category_df[['marketing_campaign_id', 'concat']]
camp_category_df.head()
# Out:
#    marketing_campaign_id                                             concat
# 0                 771022  grocery>deli>pre-sliced deli>turkey>nan>nan>na...
# 1                 771053  grocery>deli>pre-sliced deli>italian>nan>nan>n...
# 2                 771053  grocery>deli>salami & italian meats>salami>nan...
# 3                 771066  grocery>deli>pre-sliced deli>italian>nan>nan>n...
# 4                 771072  grocery>meat>bacon & breakfast meats>nan>nan>n...

# %% [markdown]
# ### Merge campaign targetted keywords with campaign category

# %%
camp_key_cat_df = pd.merge(filtered_targetted_keywords, camp_category_df, left_on='marketing_campaign_id', right_on='marketing_campaign_id', how='inner')
camp_key_cat_df.shape
# Out:
# (2160, 6)

# %%
len(filtered_targetted_keywords['marketing_campaign_id'].unique())
# Out:
# 131

# %%
len(filtered_targetted_keywords['text'].unique())
# Out:
# 495

# %%
len(camp_key_cat_df['marketing_campaign_id'].unique())
# Out:
# 122

# %%
len(camp_key_cat_df['text'].unique())
# Out:
# 471

# %%
camp_key_cat_df.head()
# Out:
#    marketing_campaign_id            text  request  response        RR  \
# 0                 771022  low sodium ham    192.0       4.0  2.083333
# 1                 771022     lunch meats     19.0       0.0  0.000000
# 2                 771022   luncheon meat     43.0       0.0  0.000000
# 3                 771022  lunchmeat deli     14.0       1.0  7.142857
# 4                 771022            meat   1652.0       0.0  0.000000
#
#                                               concat
# 0  grocery>deli>pre-sliced deli>turkey>nan>nan>na...
# 1  grocery>deli>pre-sliced deli>turkey>nan>nan>na...
# 2  grocery>deli>pre-sliced deli>turkey>nan>nan>na...
# 3  grocery>deli>pre-sliced deli>turkey>nan>nan>na...
# 4  grocery>deli>pre-sliced deli>turkey>nan>nan>na...

# %%
camp_key_cat_df.isnull().sum()
# Out:
# marketing_campaign_id    0
# text                     0
# request                  0
# response                 0
# RR                       0
# concat                   0
# dtype: int64

# %%
camp_key_cat_df[camp_key_cat_df['text']=='beef']
# Out:
#     marketing_campaign_id  text  request  response        RR  \
# 80                 771120  beef   2152.0       2.0  0.092937
#
#                                        concat
# 80  grocery>meat>hot dogs>nan>nan>nan>nan>nan

# %%
key_cat_grouped = camp_key_cat_df.groupby(['text', 'concat'], as_index=False).first()

# Step 3: Drop duplicate combinations (this is automatically handled by the groupby and first combination)
key_cat_grouped = key_cat_grouped.drop_duplicates(subset=['text', 'concat'])

# %%
key_cat_grouped.head()
# Out:
#               text                                             concat  \
# 0  8 oclock coffee  grocery>beverages>coffee>espresso>nan>nan>nan>nan
# 1  8 oclock coffee    grocery>beverages>coffee>ground>nan>nan>nan>nan
# 2              aha        grocery>beverages>soda>cola>nan>nan>nan>nan
# 3              aha  grocery>beverages>soda>ginger ale>nan>nan>nan>nan
# 4              aha  grocery>beverages>soda>lemon - lime>nan>nan>na...
#
#    marketing_campaign_id  request  response        RR
# 0                 817317     15.0       1.0  6.666667
# 1                 817317     15.0       1.0  6.666667
# 2                 850970     61.0       0.0  0.000000
# 3                 850970     61.0       0.0  0.000000
# 4                 850970     61.0       0.0  0.000000

# %%
key_cat_grouped.shape
# Out:
# (2013, 6)

# %%
targetted_keywords_category_mapp = key_cat_grouped[['text', 'concat']]
targetted_keywords_category_mapp.shape
# Out:
# (2013, 2)

# %%
targetted_keywords_category_mapp.head()
# Out:
#               text                                             concat
# 0  8 oclock coffee  grocery>beverages>coffee>espresso>nan>nan>nan>nan
# 1  8 oclock coffee    grocery>beverages>coffee>ground>nan>nan>nan>nan
# 2              aha        grocery>beverages>soda>cola>nan>nan>nan>nan
# 3              aha  grocery>beverages>soda>ginger ale>nan>nan>nan>nan
# 4              aha  grocery>beverages>soda>lemon - lime>nan>nan>na...

# %%
len(targetted_keywords_category_mapp['text'].unique())
# Out:
# 471

# %%
# targetted_keywords_category_mapp.to_csv('targetted_keywords_category_mapp.csv', index=False)

# %%
# Adding scores to mappings

# %%
# Adding scores to mappings
# s3://os-search-relevancy-data/prod/keyword_category_data_v2_10008513.csv

# %%
# redis_mapping_df = pd.read_csv("keyword_category_data_v2_10008513_Redis.csv")
# redis_mapping_df.head()

# %%
# # Group by 'keywords' and find the category with the highest 'scores'
# top_categories = redis_mapping_df.loc[redis_mapping_df.groupby('keyword')['count'].idxmax()]
# top_categories.head()

# %%
# redis_mapping_df[redis_mapping_df['keyword']=='spin']

# %%
# top_categories[top_categories['keyword']=='spin']

# %%
# top_categories['top_score'] = top_categories['count'] - (top_categories['count']*0.25) #25% less scores is added

# %%
# 1988.8-(1988.8*0.20)

# %%
# targetted_keywords_category_mapp_V2 = pd.merge(targetted_keywords_category_mapp, top_categories[['keyword', 'top_score']], left_on='text', right_on='keyword', how='left')
# targetted_keywords_category_mapp_V2.head()

# %%
# targetted_keywords_category_mapp_V2[targetted_keywords_category_mapp_V2['text']=='spin']

# %% [markdown]
# ### Extract the phrase variation of targetted keywords

# %%
# Function for the manipulations on the targeted keywords
def targeted_keywords_manipulation(targeted_keywords) -> pd.DataFrame:
    targeted_keywords["lower_tar_keyword"] = (targeted_keywords["text"].str.lower().str.strip())
    targeted_keywords = targeted_keywords.loc[(~(targeted_keywords["lower_tar_keyword"].isna())) & (targeted_keywords["lower_tar_keyword"] != "")]    
    return targeted_keywords.lower_tar_keyword

# %%
# Function for the manipulations on the search queries
def search_query_manipulation(search_queries)->Tuple[pd.DataFrame, List[str]]:
    search_queries["lower_search_keyword"] = search_queries["keywords"].str.lower().str.strip()
    search_query_df_v2 = (
        search_queries.groupby(["trimmed_keyword", "lower_search_keyword", "word_cnt"])
                                .agg({"request": "sum", "response": "sum"})
                                .reset_index()
                                .sort_values(by="request", ascending=False)
                                )

    phrase_df = search_query_df_v2.copy()
    phrase_df = phrase_df.rename(
                                columns={
                                    "lower_search_keyword": "phrase_keyword",
                                    "request": "phrase_request",
                                    "response": "phrase_response_cnt",
                                }
                                ).drop(columns=["word_cnt"])

    # Create a list with phrase candidates
    phrase_set_lst = phrase_df["phrase_keyword"].tolist()
    return phrase_df, phrase_set_lst

# %%
cleaned_targetted_keywords = targeted_keywords_manipulation(targetted_keywords_category_mapp)
cleaned_targetted_keywords = pd.DataFrame(cleaned_targetted_keywords) # dataset should be in dataframe
cleaned_targetted_keywords.head()
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_16252\3085276221.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targeted_keywords["lower_tar_keyword"] = (targeted_keywords["text"].str.lower().str.strip())
#   lower_tar_keyword
# 0   8 oclock coffee
# 1   8 oclock coffee
# 2               aha
# 3               aha
# 4               aha

# %%
phrase_df, phrase_set_lst = search_query_manipulation(requests_df)
phrase_set_lst   # This has to be in series
# Out:
# ['milk',
#  'eggs',
#  'water',
#  'ground beef',
#  'bread',
#  'ice cream',
#  'butter',
#  'chicken',
#  'bacon',
#  'watermelon',
#  'cream cheese',
#  'chicken breast',
#  'yogurt',
#  'olive oil',
#  'pasta',
#  'lettuce',
#  'bananas',
#  'coffee',
#  'sour cream',
#  'cereal',
#  'strawberries',
#  'potatoes',
#  'tomatoes',
#  'tide',
#  'paper towels',
#  'steak',
#  'cheese',
#  'chips',
#  'hot dogs',
#  'orange juice',
#  'pepsi',
#  'tomato',
#  'american cheese',
#  'toilet paper',
#  'ground turkey',
#  'rice',
#  'shrimp',
#  'salad',
#  'grapes',
#  'broccoli',
#  'gatorade',
#  'onion',
#  'peanut butter',
#  'cottage cheese',
#  'soda',
#  'apples',
#  'corn',
#  'tuna',
#  'star wars oreo',
#  'cucumber',
#  'sausage',
#  'avocado',
#  'https://bit.ly/3jnsjeh?r=qr',
#  'salmon',
#  'almond milk',
#  'carrots',
#  'blueberries',
#  'spinach',
#  'coke',
#  'garlic',
#  'paper plates',
#  'seltzer',
#  'ketchup',
#  'onions',
#  'mayo',
#  'dawn',
#  'mozzarella',
#  'sugar',
#  'cookies',
#  'rolls',
#  'ham',
#  'peppers',
#  'turkey',
#  'salsa',
#  'oreo',
#  'banana',
#  'shredded cheese',
#  'scott',
#  'peaches',
#  'bagels',
#  'starbucks',
#  'ritz',
#  'celery',
#  'pasta sauce',
#  'cascade',
#  'downy',
#  'pull-ups',
#  'air conditioner',
#  'cherries',
#  'swiffer',
#  'crackers',
#  'pizza',
#  'greek yogurt',
#  'half and half',
#  'tomato sauce',
#  'waffles',
#  'outshine',
#  'gain',
#  'red onion',
#  'creamer',
#  'dove',
#  'kleenex',
#  'fruit',
#  'heavy cream',
#  'poise',
#  'popcorn',
#  'chicken thighs',
#  'chobani',
#  'olipop',
#  'french fries',
#  'cottonelle',
#  'hummus',
#  'chicken nuggets',
#  'pickles',
#  'huggies',
#  'lemon',
#  'juice',
#  'granola',
#  'salami',
#  'lemons',
#  'doritos',
#  'chicken broth',
#  'viva',
#  'pretzels',
#  'snacks',
#  'gerber',
#  'zevo',
#  'pineapple',
#  'febreze',
#  'pantene',
#  'pancake mix',
#  'honey',
#  'red baron',
#  'goodnites',
#  'pepperoni',
#  'coffee creamer',
#  'u by kotex',
#  'hint',
#  'bubba burger',
#  'ghirardelli',
#  'cheerios',
#  'dreft',
#  'english muffins',
#  'essentia',
#  'nabisco',
#  'halls',
#  'mr. clean',
#  'herbal essences',
#  'nesquik',
#  'oatmeal',
#  'butterball',
#  'chicken wings',
#  'candy',
#  'nido',
#  'flour',
#  'burgers',
#  'syrup',
#  'hood',
#  'del real foods',
#  'ground chicken',
#  'taylor farms',
#  'wow bao',
#  'mielle',
#  'bushs',
#  'tortilla chips',
#  'planet oat milk',
#  'the laughing cow',
#  'poland spring',
#  'pine-sol',
#  'jacks pizza',
#  'heluva good!',
#  'diamond crystal',
#  'earthbound farm',
#  'chips ahoy!',
#  'nestle nido',
#  'hills bros.',
#  'zucchini',
#  'perdue',
#  'green beans',
#  'cheddar cheese',
#  'mushrooms',
#  'pork chops',
#  'potato',
#  'frozen fruit',
#  'bacardi',
#  'beef',
#  'goldfish',
#  'apple juice',
#  'dogfish head',
#  'romaine',
#  'feta',
#  'cilantro',
#  'diet coke',
#  'ricotta',
#  'lobster',
#  'cake',
#  'napkins',
#  'cucumbers',
#  'frozen pizza',
#  'italian bread',
#  'tortilla',
#  'potato chips',
#  'ginger ale',
#  'olives',
#  'mustard',
#  'snapple',
#  'whole milk',
#  'deli',
#  'spaghetti',
#  'basil',
#  'taco seasoning',
#  'mac and cheese',
#  'chocolate',
#  'laundry detergent',
#  'frozen vegetables',
#  'turkey hill',
#  'tissues',
#  'pizza sauce',
#  'tomato paste',
#  'breakfast sausage',
#  'parmesan cheese',
#  'tortillas',
#  'hamburger buns',
#  'parmesan',
#  'whipped cream',
#  'ramen',
#  'bounty',
#  'soy sauce',
#  'white bread',
#  'oranges',
#  'asparagus',
#  'swiss cheese',
#  'fries',
#  'chocolate chips',
#  'salt',
#  'garlic powder',
#  'pizza dough',
#  'jelly',
#  'deli ham',
#  'black beans',
#  'parsley',
#  'lemonade',
#  'bread crumbs',
#  'provolone',
#  'toothpaste',
#  'jello',
#  'red pepper',
#  'entenmanns',
#  'oat milk',
#  'pork',
#  'meat',
#  'oreos',
#  'turkey bacon',
#  'spaghetti sauce',
#  'pepper',
#  'ribs',
#  'strawberry',
#  'special k',
#  'sprite',
#  'paper towel',
#  'oil',
#  'meatballs',
#  'rye bread',
#  'pringles',
#  'salad dressing',
#  'yasso',
#  'garlic bread',
#  'string cheese',
#  'mashed potatoes',
#  'shampoo',
#  'blue bunny',
#  'ranch',
#  'bbq sauce',
#  'coconut milk',
#  'mayonnaise',
#  'sweet potato',
#  'lime',
#  'chicken tenders',
#  'croutons',
#  'shelfadz.link/93r54',
#  'garbage bags',
#  'barilla',
#  'ice',
#  'cantaloupe',
#  'hamburger',
#  'soup',
#  'chicken sausage',
#  'bakery',
#  'hot dog',
#  'ravioli',
#  'pancakes',
#  'turkey breast',
#  'vinegar',
#  'italian dressing',
#  'pork roll',
#  'tostitos',
#  'lemon juice',
#  'deli turkey',
#  'bleach',
#  'jasmine rice',
#  'fairlife',
#  'fish',
#  'pesto',
#  'foil',
#  'beans',
#  'baked beans',
#  'hamburger rolls',
#  'aluminum foil',
#  'limes',
#  'granola bars',
#  'cranberry juice',
#  'hot dog buns',
#  'hand soap',
#  'shelfadz.link/1s3zf',
#  'roast beef',
#  'cool whip',
#  'nutella',
#  'sauce',
#  'hot dog rolls',
#  'turkey sausage',
#  'white rice',
#  'mango',
#  'graham crackers',
#  'organic milk',
#  'lays',
#  'turkey hill ice cream',
#  'cake mix',
#  'apple sauce',
#  'egg',
#  'gum',
#  'hershey',
#  'relish',
#  'cherry tomatoes',
#  'oikos',
#  'hamburgers',
#  'dove soap',
#  'italian sausage',
#  'london broil',
#  'dr pepper',
#  'vegetable oil',
#  'cabbage',
#  'bagel',
#  'fage',
#  'dish soap',
#  'ginger',
#  'crab',
#  'guacamole',
#  'trash bags',
#  'iced tea',
#  'pure life',
#  'maple syrup',
#  'gluten free',
#  'brown sugar',
#  'muffins',
#  'baking soda',
#  'eggo',
#  'rotisserie chicken',
#  'green pepper',
#  'mozzarella cheese',
#  'taco kit',
#  'coconut water',
#  'tortellini',
#  'hotdogs',
#  'raspberries',
#  'spring water',
#  'apple',
#  'applesauce',
#  'raisin bran',
#  'ice pops',
#  'stouffers',
#  '647',
#  'protein',
#  'pudding',
#  'noodles',
#  'wraps',
#  'lysol',
#  'shredded lettuce',
#  'bologna',
#  'rice cakes',
#  'body wash',
#  'chocolate bar',
#  'taco shells',
#  'little bites',
#  'diet pepsi',
#  'iced coffee',
#  'marinara sauce',
#  'cauliflower',
#  'penne',
#  'coffee mate',
#  'plums',
#  'almonds',
#  'bottled water',
#  'onion powder',
#  'cheddar',
#  'burger',
#  'donuts',
#  'charmin',
#  'potato salad',
#  'cat food',
#  'wheat bread',
#  'cheese sticks',
#  'frosted flakes',
#  'taco',
#  'pop tarts',
#  'wings',
#  'mints',
#  'chocolate candy',
#  'lactaid',
#  'brown rice',
#  'perdue chicken',
#  'kit kat',
#  'italian ice',
#  '00000008660533',
#  'sugar free candy',
#  'dog food',
#  '08660533',
#  'fruit snacks',
#  'crab legs',
#  'colgate',
#  'shredded cheddar',
#  'cat litter',
#  'pineapple juice',
#  'sweet potatoes',
#  'hershey kisses',
#  'pita',
#  'crushed tomatoes',
#  'frozen broccoli',
#  'sliced cheese',
#  'baby carrots',
#  'coca cola',
#  'cole slaw',
#  'hard candy',
#  'bell pepper',
#  'kale',
#  'diced tomatoes',
#  'black olives',
#  'egg noodles',
#  'english muffin',
#  'hot sauce',
#  'ranch dressing',
#  'coke zero',
#  'jimmy dean',
#  'beef broth',
#  'sushi',
#  'ensure',
#  'frozen corn',
#  'egg whites',
#  'arugula',
#  'whole wheat bread',
#  'raos',
#  'grape tomatoes',
#  'orzo',
#  'baby wipes',
#  'sugar free chocolate',
#  'eggplant',
#  'sauerkraut',
#  'gluten free pasta',
#  'annies',
#  'thomas',
#  'hot pockets',
#  'protein bars',
#  'chewing gum',
#  'candy bars',
#  'peanuts',
#  'christmas chocolate',
#  'trail mix',
#  'ice tea',
#  'sparkling water',
#  'catering',
#  'cold brew',
#  'snack pack',
#  'k cups',
#  'ground coffee',
#  'christmas candy',
#  'sandwich bags',
#  'shelfadz.link/xgfbv',
#  'wipes',
#  'sugar free gum',
#  'easter candy',
#  'nuts',
#  'vegetables',
#  'alfredo sauce',
#  'marinara',
#  'ice breakers',
#  'shop',
#  'extra virgin olive oil',
#  'halloween candy',
#  'https://bit.ly/4aqg2on?r=qr',
#  'vitamin water',
#  'distilled water',
#  'ajinomoto',
#  'easter chocolate',
#  'valentines day candy',
#  'spring mix',
#  'ice cream cake',
#  'reeses peanut butter cups',
#  'holiday candy',
#  'arizona',
#  'pie crust',
#  'protein pasta',
#  'chobani creamer',
#  'coffee pods',
#  'haagen',
#  'lavazza',
#  'nature valley',
#  'crystal light',
#  'kielbasa',
#  'bell peppers',
#  'chips ahoy',
#  'flowers',
#  'french toast',
#  'chicken breasts',
#  'mexican cheese',
#  'breakfast',
#  'tuna fish',
#  'salad kit',
#  'beer',
#  'dove body wash',
#  'chicken patties',
#  'pretzel',
#  'lean cuisine',
#  'peas',
#  'valentines candy',
#  'quinoa',
#  'goya',
#  'lasagna',
#  'sponges',
#  'clorox',
#  'minced garlic',
#  'uncrustables',
#  'walnuts',
#  'dill',
#  'chocolate milk',
#  'vegan',
#  'cookie dough',
#  'cupcakes',
#  'frozen meals',
#  'frozen breakfast',
#  'powerade',
#  'tater tots',
#  'whole chicken',
#  'grated cheese',
#  'frozen pancakes',
#  'frozen peas',
#  'buns',
#  'velveeta',
#  'shelfadz.link/gm75c',
#  'scallions',
#  'clams',
#  'tea',
#  'macaroni and cheese',
#  'black pepper',
#  'shelfadz.link/3msap',
#  'brownies',
#  'peach',
#  'white vinegar',
#  'veggie burger',
#  'coleslaw',
#  'knorr',
#  'sunscreen',
#  'rice krispies',
#  'friendlys',
#  'brownie mix',
#  'minute rice',
#  'carrot',
#  'skinny pop',
#  'fried chicken',
#  'frozen spinach',
#  'kashi',
#  'frozen dinners',
#  'cheez it',
#  'feta cheese',
#  'burger buns',
#  'refried beans',
#  'ragu',
#  'orange',
#  'french toast sticks',
#  'cooking spray',
#  'fresh express',
#  'rigatoni',
#  'deodorant',
#  'lunchables',
#  'macaroni',
#  'breakfast sandwich',
#  'ice cream cones',
#  'pillsbury',
#  'plastic cups',
#  'alfredo',
#  'detergent',
#  'always',
#  '2% milk',
#  'organic chicken',
#  'tofu',
#  'saltines',
#  'skippy',
#  'chili',
#  'smart water',
#  'fresh mozzarella',
#  'smart ones',
#  'protein bar',
#  'belvita',
#  'baby spinach',
#  'beets',
#  'potato bread',
#  'romaine lettuce',
#  'cinnamon',
#  'vanilla extract',
#  'kodiak',
#  'chicken salad',
#  'healthy choice',
#  'avocados',
#  'teriyaki sauce',
#  'lunch meat',
#  'peanut butter crackers',
#  'panko',
#  'vanilla ice cream',
#  'frozen waffles',
#  'chia seeds',
#  'grape jelly',
#  'biscuits',
#  'taco sauce',
#  'granola bar',
#  'yellow onion',
#  'ground meat',
#  'kids snacks',
#  'avocado oil',
#  'seafood',
#  'chocolate chip cookies',
#  'chicken strips',
#  'apple cider vinegar',
#  'cashews',
#  'el yucateco',
#  'https://checkout51.app.link/e/4z1qw8kmshb',
#  'healthy snacks',
#  'frosting',
#  'cakes',
#  'tylenol',
#  'corn on the cob',
#  'capri sun',
#  'ziti',
#  'yoplait',
#  'pads',
#  'turkey burgers',
#  'tide pods',
#  'cheetos',
#  'flank steak',
#  'pam',
#  'whip cream',
#  'rotini',
#  'chicken stock',
#  'mushroom',
#  'blueberry',
#  'batteries',
#  'kelloggs cereal',
#  'frozen chicken',
#  'rotisserie',
#  'gravy',
#  'macaroni salad',
#  'diapers',
#  'pampers',
#  'poland spring water',
#  'chocolate syrup',
#  'danimals',
#  'deli cheese',
#  'stonyfield',
#  'green tea',
#  'crest',
#  'canned chicken',
#  'shredded mozzarella',
#  'gluten free bread',
#  'vanilla yogurt',
#  'produce',
#  'prego',
#  'crab meat',
#  'instant coffee',
#  'pork loin',
#  'hash browns',
#  'frozen shrimp',
#  'nectarines',
#  'stir fry',
#  'red peppers',
#  'parchment paper',
#  'goat cheese',
#  'panera',
#  'shelfadz.link/zifoa',
#  'raisins',
#  'avacado',
#  'marinade',
#  'queso',
#  'almond butter',
#  'keto',
#  'grilled chicken',
#  'blackberries',
#  'scott toilet paper',
#  'pears',
#  'chicken cutlets',
#  'https://bit.ly/3yyum8v?r=qr',
#  'minute maid',
#  'block cheese',
#  'plain greek yogurt',
#  'root beer',
#  'shaving cream',
#  'chuck roast',
#  'wheat thins',
#  'plates',
#  'sourdough',
#  'pork shoulder',
#  'canola oil',
#  'spam',
#  'mouthwash',
#  'honey ham',
#  'blue cheese',
#  'half & half',
#  'marshmallows',
#  'string beans',
#  'buttermilk',
#  'coffeemate',
#  'snack packs',
#  'pork tenderloin',
#  'plant based',
#  'red potatoes',
#  'boars head',
#  'carrs',
#  'pizza rolls',
#  'lamb',
#  'pancake',
#  'gatorade zero',
#  'ruffles',
#  'cheese its',
#  'polar',
#  'yellow rice',
#  'cod',
#  'popsicles',
#  'canned tomatoes',
#  'carrs crackers',
#  'general mills',
#  'protein powder',
#  'razors',
#  'bounty paper towels',
#  'dog treats',
#  'honey mustard',
#  'poppi',
#  'pancake syrup',
#  'popcorn chicken',
#  'dressing',
#  'canada dry',
#  'cream',
#  'rana',
#  '00041190065882',
#  'fancy feast',
#  'tomato soup',
#  'oats',
#  'kettle chips',
#  'edamame',
#  'yeast',
#  'vanilla',
#  'cheese crackers',
#  'snack',
#  'red wine vinegar',
#  'lime juice',
#  'bacon bits',
#  'pool',
#  'corn flakes',
#  'ice cream sandwich',
#  'dip',
#  'keebler',
#  'activia',
#  'marshmallow',
#  'breyers',
#  'pita chips',
#  'caesar dressing',
#  'tropicana',
#  'mozzarella sticks',
#  'little debbie',
#  'skirt steak',
#  'fruit loops',
#  'shelfadz.link/jm1jx',
#  'tahini',
#  'cracker',
#  'lucky charms',
#  'hebrew national',
#  'frozen food',
#  'animal crackers',
#  'conditioner',
#  'cheez its',
#  'pizza crust',
#  'dark chocolate',
#  'chicken thigh',
#  'variety chips',
#  'pure leaf',
#  'raid',
#  'sesame oil',
#  'prosciutto',
#  'frozen',
#  'sprinkles',
#  'deli meat',
#  'swiss',
#  'cold cuts',
#  'listerine',
#  'ground pork',
#  'soap',
#  'cups',
#  'whipped topping',
#  'cocoa powder',
#  'cracker barrel',
#  'tissue',
#  'clementines',
#  'vegan sausage',
#  'baby food',
#  'digiorno',
#  'tampons',
#  'protein snack',
#  'kombucha',
#  'sunflower seeds',
#  'frozen dinner',
#  'pop tart',
#  'chicken tenderloins',
#  'v8',
#  'whipped cream cheese',
#  'provolone cheese',
#  'vegetarian',
#  'naan',
#  'paprika',
#  'poptarts',
#  'healthy snack',
#  'kiwi',
#  'elbow',
#  'angel hair',
#  'mini pancakes',
#  'cheesecake',
#  'vodka sauce',
#  'cherry',
#  'kidney beans',
#  'brussel sprouts',
#  'freezer bags',
#  'water bottles',
#  'ronzoni',
#  'dryer sheets',
#  'mountain dew',
#  'pie',
#  'icing',
#  'sargento',
#  'razor',
#  'rao',
#  'talenti',
#  'oregano',
#  'frozen veggies',
#  'unsalted butter',
#  'bowl and basket pasta',
#  'vegan meat',
#  'vegan chicken',
#  'bone broth',
#  'eggo waffles',
#  'dino nuggets',
#  'pumpkin',
#  'honey turkey',
#  'breadcrumbs',
#  'drumsticks',
#  'ricotta cheese',
#  'mint',
#  'land o lakes',
#  'dumplings',
#  'old spice',
#  'sourdough bread',
#  'tin foil',
#  'chick peas',
#  'coffee filters',
#  'black bean burger',
#  'international delight',
#  'chicken drumsticks',
#  'quest',
#  'nathans',
#  'shelfadz.link/kx4hc',
#  'berries',
#  'ritz crackers',
#  'paper bowls',
#  'chocolate pudding',
#  'organic cereal',
#  'heavy whipping cream',
#  'organic eggs',
#  'saltine crackers',
#  'baked chips',
#  'gardein',
#  'lactose free milk',
#  'green peppers',
#  'halo top',
#  'chop meat',
#  'juice box',
#  'bbq chips',
#  'baking powder',
#  'jam',
#  'kotex',
#  'chobani yogurt',
#  'chomps',
#  'dijon mustard',
#  'puffs',
#  'tea bags',
#  'juice boxes',
#  'linguine',
#  'shelfadz.link/2husg',
#  'buffalo chicken',
#  'school snacks',
#  'goya rice',
#  'shelfadz.link/b64hx',
#  'impossible',
#  'pickle',
#  'breakfast bars',
#  'nuggets',
#  'ac',
#  'elbow macaroni',
#  'haagen dazs',
#  'tru fru',
#  'italian seasoning',
#  'apple pie',
#  'spindrift',
#  'cereal bars',
#  'cinnamon toast crunch',
#  'laundry',
#  'beef jerky',
#  'potatos',
#  'pork chop',
#  'squash',
#  'old el paso',
#  'polar seltzer',
#  'frozen breakfast sandwich',
#  'onion dip',
#  'kelloggs',
#  'wonder buns',
#  'coconut oil',
#  'pita bread',
#  'beef hot dogs',
#  'apple jacks',
#  'sazon',
#  'gold fish',
#  'windex',
#  'toilet tissue',
#  'entenmann',
#  'pasta shells',
#  'dishwasher',
#  'taylor ham',
#  'fresh fruit',
#  'boneless chicken breast',
#  'barilla pasta',
#  'cherry tomato',
#  'shelfadz.link/sxeaw',
#  'icecream',
#  'granola cereal',
#  'balsamic vinegar',
#  '00048121102081',
#  'vegan food',
#  'spaghettios',
#  'shredded wheat',
#  'ice cream bars',
#  'fabric softener',
#  'rice pudding',
#  'birds eye',
#  'protein shake',
#  'wasa',
#  'utz',
#  'microwave popcorn',
#  'special k cereal',
#  'propel',
#  'franks',
#  'bob evans',
#  'tastykake',
#  'banquet',
#  'chobani flip',
#  'balsamic glaze',
#  'la croix',
#  'sausage patties',
#  'whole wheat pasta',
#  'grits',
#  'chickpeas',
#  'fritos',
#  'depends',
#  'onion rings',
#  'shredded chicken',
#  'salad mix',
#  'stok',
#  'elbows',
#  'green onion',
#  'veggie burgers',
#  'scallops',
#  'chef boyardee',
#  'applegate',
#  'liquid iv',
#  'popsicle',
#  'evaporated milk',
#  'splenda',
#  'herrs',
#  'cooking oil',
#  'pedialyte',
#  'mixed vegetables',
#  'coconut',
#  'shallot',
#  'bagel bites',
#  'canned corn',
#  'flour tortillas',
#  'fruit bars',
#  'siete',
#  ...]

# %%
# Function to find the phrase variations
def find_phrase_variations(targetted_keywords: List[str], search_query: List[str], score_cutoff=100):
    targeted_query_len = len(targetted_keywords)
    
    filtered_phrase_set = [query for query in search_query if targetted_keywords in query]
    
    matches = process.extract(targetted_keywords, filtered_phrase_set, scorer=fuzz.token_set_ratio, limit=None)
    score_filtered_lst = [key for key, score, _ in matches if score == score_cutoff]
    
    return score_filtered_lst

# %%
from tqdm import tqdm
tqdm.pandas(desc="Finding the subqueries")
cleaned_targetted_keywords.loc[:, "matching_targets"] = cleaned_targetted_keywords["lower_tar_keyword"].progress_apply(lambda x: find_phrase_variations(x, phrase_set_lst))
cleaned_targetted_keywords
# Out:
# Finding the subqueries: 100%|██████████████████████████████████████████████████████| 2013/2013 [03:08<00:00, 10.67it/s]
#      lower_tar_keyword                                   matching_targets
# 0      8 oclock coffee  [8 oclock coffee, 8 oclock coffee pods, 8 oclo...
# 1      8 oclock coffee  [8 oclock coffee, 8 oclock coffee pods, 8 oclo...
# 2                  aha  [aha, aha seltzer, aha water, aha sparkling wa...
# 3                  aha  [aha, aha seltzer, aha water, aha sparkling wa...
# 4                  aha  [aha, aha seltzer, aha water, aha sparkling wa...
# ...                ...                                                ...
# 2008            wymans  [wymans, wymans frozen, wymans frozen fruit, f...
# 2009    yellow mustard  [yellow mustard, frenchs yellow mustard, yello...
# 2010      yellow onion  [yellow onion, organic yellow onion, diced yel...
# 2011         zip locks  [zip locks, quart zip locks, zip locks bags, z...
# 2012           ziplocs  [ziplocs, large ziplocs, small ziplocs, ziploc...
#
# [2013 rows x 2 columns]

# %%
filtered_df = cleaned_targetted_keywords[cleaned_targetted_keywords["matching_targets"].apply(len) == 0]
targeted_matched_keywords = cleaned_targetted_keywords.explode("matching_targets")
print("Pre Shape: ", targeted_matched_keywords.shape)
targeted_matched_keywords = targeted_matched_keywords.drop_duplicates(subset=['lower_tar_keyword', 'matching_targets'])
print("Post Shape: ", targeted_matched_keywords.shape)
# Out:
# Pre Shape:  (211920, 2)
# Post Shape:  (48161, 2)

# %%
targeted_matched_keywords.head()
# Out:
#   lower_tar_keyword       matching_targets
# 0   8 oclock coffee        8 oclock coffee
# 0   8 oclock coffee   8 oclock coffee pods
# 0   8 oclock coffee  8 oclock coffee beans
# 2               aha                    aha
# 2               aha            aha seltzer

# %%
targeted_matched_keywords = pd.merge(targeted_matched_keywords, phrase_df[["phrase_keyword", "phrase_request", "phrase_response_cnt"]], how="inner", left_on="matching_targets", right_on="phrase_keyword")
targeted_matched_keywords = targeted_matched_keywords.drop('phrase_keyword', axis=1)
targeted_matched_keywords['phrase_response_rate'] = targeted_matched_keywords['phrase_response_cnt']*100/ targeted_matched_keywords['phrase_request']
targeted_matched_keywords.head()
# print(
#     "Distinct targeted keywords with phrase candidates: ",
#     targeted_keyword_df_v4.lower_tar_keyword.nunique(),
# )
# targeted_keyword_df_v4.to_csv(
#     f"wakefern_phrase_variations.tsv", sep="\t", index=False)
# Out:
#   lower_tar_keyword       matching_targets  phrase_request  \
# 0   8 oclock coffee        8 oclock coffee              15
# 1   8 oclock coffee   8 oclock coffee pods               2
# 2              pods   8 oclock coffee pods               2
# 3   8 oclock coffee  8 oclock coffee beans               2
# 4               aha                    aha              61
#
#    phrase_response_cnt  phrase_response_rate
# 0                    1              6.666667
# 1                    0              0.000000
# 2                    0              0.000000
# 3                    2            100.000000
# 4                    0              0.000000

# %%
phrase_cat_mapping_df = pd.merge(targeted_matched_keywords, targetted_keywords_category_mapp, left_on='lower_tar_keyword', right_on='text', how='inner')
phrase_cat_mapping_df.shape
# Out:
# (211920, 8)

# %%
phrase_cat_mapping_df = phrase_cat_mapping_df.groupby(['matching_targets', 'concat'], as_index=False).first()
phrase_cat_mapping_df.head()
# Out:
#                        matching_targets  \
# 0  $9.99 bowl * basket 2lb beef burgers
# 1  $9.99 bowl * basket 2lb beef burgers
# 2  $9.99 bowl * basket 2lb beef burgers
# 3                              %85 meat
# 4                              %85 meat
#
#                                               concat lower_tar_keyword_x  \
# 0  grocery>frozen>frozen all natural>nan>nan>nan>...             burgers
# 1  grocery>frozen>frozen meat alternatives>nan>na...             burgers
# 2          grocery>meat>hot dogs>nan>nan>nan>nan>nan                beef
# 3  grocery>breakfast & cereal>frozen breakfast>br...                meat
# 4  grocery>deli>pre-sliced deli>turkey>nan>nan>na...                meat
#
#    phrase_request  phrase_response_cnt  phrase_response_rate     text  \
# 0               1                    0                   0.0  burgers
# 1               1                    0                   0.0  burgers
# 2               1                    0                   0.0     beef
# 3               1                    0                   0.0     meat
# 4               1                    0                   0.0     meat
#
#   lower_tar_keyword_y
# 0             burgers
# 1             burgers
# 2                beef
# 3                meat
# 4                meat

# %%
phrase_cat_mapping_df[phrase_cat_mapping_df['lower_tar_keyword_x']=='steak']
# Out:
# Empty DataFrame
# Columns: [matching_targets, concat, lower_tar_keyword_x, phrase_request, phrase_response_cnt, phrase_response_rate, text, lower_tar_keyword_y]
# Index: []

# %%
targetted_keywords_category_mapp.columns
# Out:
# Index(['text', 'concat', 'lower_tar_keyword'], dtype='object')

# %%
# Handling of Branded keywords
# brand_df = pd.read_csv("brand_search_queries_395539.csv")
# brand_df.shape

# %%
# brand_df.head()

# %%
# pd.merge(phrase_cat_mapping_df, brand_df[['actual_search_query', 'extracted_brand']], left_on='matching_targets')

# %% [markdown]
# ### Renameing and append targetted and phrase matched datasets

# %%
targetted_keywords_category_mapp = targetted_keywords_category_mapp.drop('lower_tar_keyword', axis=1)

# %%
targetted_keywords_category_mapp.columns
# Out:
# Index(['text', 'concat'], dtype='object')

# %%
phrase_cat_mapping_df.columns
# Out:
# Index(['text', 'concat'], dtype='object')

# %%
# FIlter the phrase matched keywords having RR <50%
phrase_cat_mapping_df = phrase_cat_mapping_df[phrase_cat_mapping_df['phrase_response_rate']<50]
phrase_cat_mapping_df.shape
# Out:
# (152132, 8)

# %%
phrase_cat_mapping_df = phrase_cat_mapping_df.drop(['lower_tar_keyword_x', 'phrase_request', 'phrase_response_cnt', 'phrase_response_rate', 'text','lower_tar_keyword_y'], axis=1)
phrase_cat_mapping_df = phrase_cat_mapping_df.rename(columns={'matching_targets':'text', 'concat':'concat'})

# %%
targetted_keyword_category_map_final =  pd.concat([targetted_keywords_category_mapp, phrase_cat_mapping_df], axis=0, ignore_index=True)
targetted_keyword_category_map_final.shape
# Out:
# (154145, 2)

# %%
targetted_keyword_category_map_final.head()
# Out:
#               text                                             concat
# 0  8 oclock coffee  grocery>beverages>coffee>espresso>nan>nan>nan>nan
# 1  8 oclock coffee    grocery>beverages>coffee>ground>nan>nan>nan>nan
# 2              aha        grocery>beverages>soda>cola>nan>nan>nan>nan
# 3              aha  grocery>beverages>soda>ginger ale>nan>nan>nan>nan
# 4              aha  grocery>beverages>soda>lemon - lime>nan>nan>na...

# %%
phrase_cat_mapping_df.head()
# Out:
#                                    text  \
# 0  $9.99 bowl * basket 2lb beef burgers
# 1  $9.99 bowl * basket 2lb beef burgers
# 2  $9.99 bowl * basket 2lb beef burgers
# 3                              %85 meat
# 4                              %85 meat
#
#                                               concat
# 0  grocery>frozen>frozen all natural>nan>nan>nan>...
# 1  grocery>frozen>frozen meat alternatives>nan>na...
# 2          grocery>meat>hot dogs>nan>nan>nan>nan>nan
# 3  grocery>breakfast & cereal>frozen breakfast>br...
# 4  grocery>deli>pre-sliced deli>turkey>nan>nan>na...

# %%
phrase_cat_mapping_df[phrase_cat_mapping_df['text']=='salmon']
# Out:
#           text                                             concat
# 163341  salmon  grocery>frozen>frozen meals & sides>seafood en...
# 163342  salmon  grocery>frozen>frozen seafood>fish>nan>nan>nan...
# 163343  salmon  grocery>frozen>frozen seafood>shellfish>nan>na...

# %%
targetted_keyword_category_map_final[targetted_keyword_category_map_final['text']=='salmon']
# Out:
#           text                                             concat
# 1626    salmon  grocery>frozen>frozen meals & sides>seafood en...
# 1627    salmon  grocery>frozen>frozen seafood>fish>nan>nan>nan...
# 1628    salmon  grocery>frozen>frozen seafood>shellfish>nan>na...
# 124335  salmon  grocery>frozen>frozen meals & sides>seafood en...
# 124336  salmon  grocery>frozen>frozen seafood>fish>nan>nan>nan...
# 124337  salmon  grocery>frozen>frozen seafood>shellfish>nan>na...

# %%
# Adding scores to mappings
# s3://os-search-relevancy-data/prod/keyword_category_data_v2_10008513.csv

# %%
redis_mapping_df = pd.read_csv("keyword_category_data_v2_395539_Redis_20thJuly.csv")
redis_mapping_df.head()
# Out:
#       keyword category_l1 category_l2             category_l3  \
# 0        eggs     Grocery       Dairy  Eggs & Egg Substitutes
# 1        eggs     grocery       dairy  eggs & egg substitutes
# 2        eggs     grocery       dairy  eggs & egg substitutes
# 3        eggs     grocery       dairy  eggs & egg substitutes
# 4  groundbeef     Grocery        Meat                    Beef
#
#         category_l4 category_l5 category_l6  category_l7  category_l8  source  \
# 0        Fresh Eggs         NaN         NaN          NaN          NaN    auto
# 1   egg substitutes         NaN         NaN          NaN          NaN  manual
# 2             other         NaN         NaN          NaN          NaN  manual
# 3  hard cooked eggs         NaN         NaN          NaN          NaN  manual
# 4               NaN         NaN         NaN          NaN          NaN    auto
#
#        count                        tag  advertisable_sku_count
# 0  20256.400  advertisable_skus_present              71429672.0
# 1  12886.603  advertisable_skus_present                  1186.0
# 2  12758.009                        NaN                     NaN
# 3  12475.422                        NaN                     NaN
# 4  10872.000  advertisable_skus_present                497226.0

# %%
# Group by 'keywords' and find the category with the highest 'scores'
top_categories = redis_mapping_df.loc[redis_mapping_df.groupby('keyword')['count'].idxmax()]
top_categories.head()
# Out:
#               keyword category_l1 category_l2  \
# 76855               0     Grocery       Dairy
# 75769              00     Grocery      Pantry
# 56893  00000000179900     Grocery     Produce
# 77284  00000000180207     Grocery      Pantry
# 77054  00000000180401     Grocery     Produce
#
#                                   category_l3            category_l4  \
# 76855  Cottage Cheese, Cream Cheese & Spreads         Cottage Cheese
# 75769                                  Baking           Flour & Meal
# 56893                             Fresh Fruit                Peaches
# 77284                    Soups & Canned Goods  Canned Tuna & Seafood
# 77054                             Fresh Fruit               Avocados
#
#       category_l5 category_l6  category_l7  category_l8 source  count  \
# 76855         NaN         NaN          NaN          NaN   auto    3.0
# 75769         NaN         NaN          NaN          NaN   auto    3.0
# 56893         NaN         NaN          NaN          NaN   auto    4.0
# 77284        Tuna         NaN          NaN          NaN   auto    3.0
# 77054         NaN         NaN          NaN          NaN   auto    3.0
#
#                              tag  advertisable_sku_count
# 76855  advertisable_skus_present                  5395.0
# 75769  advertisable_skus_present                  7578.0
# 56893                        NaN                     NaN
# 77284  advertisable_skus_present                  5770.0
# 77054                        NaN                     NaN

# %%
redis_mapping_df[redis_mapping_df['keyword']=='groundbeef']
# Out:
#           keyword category_l1      category_l2                   category_l3  \
# 4      groundbeef     Grocery             Meat                          Beef
# 23     groundbeef     grocery  specialty shops                  ebt eligible
# 31     groundbeef     grocery             deli  roast beef & other beef cuts
# 33     groundbeef     grocery           frozen                   frozen meat
# 36     groundbeef     grocery  specialty shops                  ebt eligible
# ...           ...         ...              ...                           ...
# 81419  groundbeef     Grocery           Frozen                Frozen Seafood
# 81485  groundbeef     Grocery        Beverages                           Tea
# 81777  groundbeef     Grocery   Bread & Bakery                Packaged Bread
# 85420  groundbeef     Grocery            Dairy               Packaged Cheese
# 85581  groundbeef     Grocery            Dairy              Cream & Creamers
#
#             category_l4                   category_l5 category_l6  \
# 4                   NaN                           NaN         NaN
# 23                 meat                          beef         NaN
# 31           roast beef                           NaN         NaN
# 33          frozen beef                           NaN         NaN
# 36                 deli  roast beef & other beef cuts         NaN
# ...                 ...                           ...         ...
# 81419     Frozen Shrimp                           NaN         NaN
# 81485          Iced Tea                           NaN         NaN
# 81777             White                           NaN         NaN
# 85420     Cheese Blends                           NaN         NaN
# 85581  Heavy & Whipping                           NaN         NaN
#
#        category_l7  category_l8  source       count  \
# 4              NaN          NaN    auto  10872.0000
# 23             NaN          NaN  manual   7252.7290
# 31             NaN          NaN  manual   6408.1445
# 33             NaN          NaN  manual   6380.4927
# 36             NaN          NaN  manual   6323.9106
# ...            ...          ...     ...         ...
# 81419          NaN          NaN    auto      2.8000
# 81485          NaN          NaN    auto      2.8000
# 81777          NaN          NaN    auto      2.8000
# 85420          NaN          NaN    auto      2.4000
# 85581          NaN          NaN    auto      2.4000
#
#                              tag  advertisable_sku_count
# 4      advertisable_skus_present                497226.0
# 23                           NaN                     NaN
# 31     advertisable_skus_present                  3484.0
# 33     advertisable_skus_present                  2121.0
# 36     advertisable_skus_present                    60.0
# ...                          ...                     ...
# 81419  advertisable_skus_present                 22878.0
# 81485  advertisable_skus_present                 89982.0
# 81777  advertisable_skus_present                  5676.0
# 85420  advertisable_skus_present                 17970.0
# 85581  advertisable_skus_present                  1810.0
#
# [64 rows x 13 columns]

# %%
top_categories[top_categories['keyword']=='groundbeef']
# Out:
#       keyword category_l1 category_l2 category_l3 category_l4 category_l5  \
# 4  groundbeef     Grocery        Meat        Beef         NaN         NaN
#
#   category_l6  category_l7  category_l8 source    count  \
# 4         NaN          NaN          NaN   auto  10872.0
#
#                          tag  advertisable_sku_count  top_score
# 4  advertisable_skus_present                497226.0     8154.0

# %%
top_categories['top_score'] = top_categories['count'] - (top_categories['count']*0.25) #25% less scores is added

# %%
targetted_keyword_category_map_final.head()
# Out:
#               text                                             concat  \
# 0  8 oclock coffee  grocery>beverages>coffee>espresso>nan>nan>nan>nan
# 1  8 oclock coffee    grocery>beverages>coffee>ground>nan>nan>nan>nan
# 2              aha        grocery>beverages>soda>cola>nan>nan>nan>nan
# 3              aha  grocery>beverages>soda>ginger ale>nan>nan>nan>nan
# 4              aha  grocery>beverages>soda>lemon - lime>nan>nan>na...
#
#   trimmed_keyword
# 0   8oclockcoffee
# 1   8oclockcoffee
# 2             aha
# 3             aha
# 4             aha

# %%
# As redis data has trimmed keywords to merged with targetted keywords data we need to create trimmed columns in targetted data
targetted_keyword_category_map_final['trimmed_keyword'] = targetted_keyword_category_map_final['text'].str.strip().str.replace(' ', '')

# %%
targetted_keywords_category_score_V2 = pd.merge(targetted_keyword_category_map_final, top_categories[['keyword', 'top_score']], left_on='trimmed_keyword', right_on='keyword', how='left')
targetted_keywords_category_score_V2.head()
# Out:
#               text                                             concat  \
# 0  8 oclock coffee  grocery>beverages>coffee>espresso>nan>nan>nan>nan
# 1  8 oclock coffee    grocery>beverages>coffee>ground>nan>nan>nan>nan
# 2              aha        grocery>beverages>soda>cola>nan>nan>nan>nan
# 3              aha  grocery>beverages>soda>ginger ale>nan>nan>nan>nan
# 4              aha  grocery>beverages>soda>lemon - lime>nan>nan>na...
#
#   trimmed_keyword        keyword  top_score
# 0   8oclockcoffee  8oclockcoffee      375.0
# 1   8oclockcoffee  8oclockcoffee      375.0
# 2             aha            aha        8.1
# 3             aha            aha        8.1
# 4             aha            aha        8.1

# %%
targetted_keywords_category_score_V2 = targetted_keywords_category_score_V2.drop('keyword', axis=1)

# %%
targetted_keywords_category_score_V2[targetted_keywords_category_score_V2['text']=='ground beef']
# Out:
#               text                                     concat trimmed_keyword  \
# 69605  ground beef  grocery>meat>hot dogs>nan>nan>nan>nan>nan      groundbeef
#
#        top_score
# 69605     8154.0

# %%
# targetted_keywords_category_score_V2.drop('keyword', axis=1)
targetted_keywords_category_score_V2 = targetted_keywords_category_score_V2.drop_duplicates(subset=['text', 'concat', 'trimmed_keyword', 'top_score'])

# Replace NaN values in 'top_score' column with a specific value (e.g., 300)
targetted_keywords_category_score_V2['top_score'] = targetted_keywords_category_score_V2['top_score'].fillna(500)

# Replace NaN values with empty string in the entire DataFrame, except 'top_score'
targetted_keywords_category_score_V2 = targetted_keywords_category_score_V2.fillna('')

targetted_keywords_category_score_V2.shape
# Out:
# (152132, 4)

# %%
targetted_keywords_category_score_V2.head()
# Out:
#               text                                             concat  \
# 0  8 oclock coffee  grocery>beverages>coffee>espresso>nan>nan>nan>nan
# 1  8 oclock coffee    grocery>beverages>coffee>ground>nan>nan>nan>nan
# 2              aha        grocery>beverages>soda>cola>nan>nan>nan>nan
# 3              aha  grocery>beverages>soda>ginger ale>nan>nan>nan>nan
# 4              aha  grocery>beverages>soda>lemon - lime>nan>nan>na...
#
#   trimmed_keyword  top_score
# 0   8oclockcoffee      375.0
# 1   8oclockcoffee      375.0
# 2             aha        8.1
# 3             aha        8.1
# 4             aha        8.1

# %%
# Handling of Branded keywords
brand_df = pd.read_csv("brand_search_queries_395539.csv")
brand_df.shape
# Out:
# (579493, 3)

# %%
brand_df.head()
# Out:
#    marketplace_client_id          actual_search_query extracted_brand
# 0                 395539             *sargento sliced        sargento
# 1                 395539                   *kens lite           ken's
# 2                 395539  00 serenita bella primitivo           bella
# 3                 395539  /jolly-rancher-freezer-pops   jolly rancher
# 4                 395539                  *black bear      black bear

# %%
targetted_keywords_category_score_V2 = pd.merge(targetted_keywords_category_score_V2, brand_df[['actual_search_query', 'extracted_brand']], left_on='text', right_on='actual_search_query', how='left')
targetted_keywords_category_score_V2 = targetted_keywords_category_score_V2.drop('actual_search_query', axis=1)
targetted_keywords_category_score_V2.shape
# Out:
# (152132, 5)

# %%
targetted_keywords_category_score_V2.head()
# Out:
#               text                                             concat  \
# 0  8 oclock coffee  grocery>beverages>coffee>espresso>nan>nan>nan>nan
# 1  8 oclock coffee    grocery>beverages>coffee>ground>nan>nan>nan>nan
# 2              aha        grocery>beverages>soda>cola>nan>nan>nan>nan
# 3              aha  grocery>beverages>soda>ginger ale>nan>nan>nan>nan
# 4              aha  grocery>beverages>soda>lemon - lime>nan>nan>na...
#
#   trimmed_keyword  top_score extracted_brand
# 0   8oclockcoffee      375.0             NaN
# 1   8oclockcoffee      375.0             NaN
# 2             aha        8.1             aha
# 3             aha        8.1             aha
# 4             aha        8.1             aha

# %%
targetted_keywords_category_score_V2.isnull().sum()
# Out:
# text                   0
# concat                 0
# trimmed_keyword        0
# top_score              0
# extracted_brand    77235
# dtype: int64

# %%
# Considering the non-branded keywords only
targetted_keywords_category_score_V3 = targetted_keywords_category_score_V2[targetted_keywords_category_score_V2['extracted_brand'].isna()]
targetted_keywords_category_score_V3.head()
# Out:
#                text                                             concat  \
# 0   8 oclock coffee  grocery>beverages>coffee>espresso>nan>nan>nan>nan
# 1   8 oclock coffee    grocery>beverages>coffee>ground>nan>nan>nan>nan
# 9         air fryer  grocery>frozen>frozen meat>frozen poultry>nan>...
# 10          alfredo  grocery>beverages>drink mixes>nan>nan>nan>nan>nan
# 11          alfredo        grocery>beverages>tea>black>nan>nan>nan>nan
#
#    trimmed_keyword  top_score extracted_brand
# 0    8oclockcoffee      375.0             NaN
# 1    8oclockcoffee      375.0             NaN
# 9         airfryer        7.5             NaN
# 10         alfredo      240.0             NaN
# 11         alfredo      240.0             NaN

# %%
targetted_keywords_category_score_V3.shape
# Out:
# (77235, 5)

# %%
# Delimiting the similar category column
targetted_keywords_category_score_V3[['category_l1', 'category_l2', 'category_l3','category_l4','category_l5','category_l6','category_l7','category_l8']] = targetted_keywords_category_score_V3['concat'].str.split(">", expand=True)
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_16252\970406254.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targetted_keywords_category_score_V3[['category_l1', 'category_l2', 'category_l3','category_l4','category_l5','category_l6','category_l7','category_l8']] = targetted_keywords_category_score_V3['concat'].str.split(">", expand=True)
# C:\Users\mayur\AppData\Local\Temp\ipykernel_16252\970406254.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targetted_keywords_category_score_V3[['category_l1', 'category_l2', 'category_l3','category_l4','category_l5','category_l6','category_l7','category_l8']] = targetted_keywords_category_score_V3['concat'].str.split(">", expand=True)
# C:\Users\mayur\AppData\Local\Temp\ipykernel_16252\970406254.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targetted_keywords_category_score_V3[['category_l1', 'category_l2', 'category_l3','category_l4','category_l5','category_l6','category_l7','category_l8']] = targetted_keywords_category_score_V3['concat'].str.split(">", expand=True)
# C:\Users\mayur\AppData\Local\Temp\ipykernel_16252\970406254.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targetted_keywords_category_score_V3[['category_l1', 'category_l2', 'category_l3','category_l4','category_l5','category_l6','category_l7','category_l8']] = targetted_keywords_category_score_V3['concat'].str.split(">", expand=True)
# C:\Users\mayur\AppData\Local\Temp\ipykernel_16252\970406254.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targetted_keywords_category_score_V3[['category_l1', 'category_l2', 'category_l3','category_l4','category_l5','category_l6','category_l7','category_l8']] = targetted_keywords_category_score_V3['concat'].str.split(">", expand=True)
# C:\Users\mayur\AppData\Local\Temp\ipykernel_16252\970406254.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targetted_keywords_category_score_V3[['category_l1', 'category_l2', 'category_l3','category_l4','category_l5','category_l6','category_l7','category_l8']] = targetted_keywords_category_score_V3['concat'].str.split(">", expand=True)
# C:\Users\mayur\AppData\Local\Temp\ipykernel_16252\970406254.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targetted_keywords_category_score_V3[['category_l1', 'category_l2', 'category_l3','category_l4','category_l5','category_l6','category_l7','category_l8']] = targetted_keywords_category_score_V3['concat'].str.split(">", expand=True)
# C:\Users\mayur\AppData\Local\Temp\ipykernel_16252\970406254.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targetted_keywords_category_score_V3[['category_l1', 'category_l2', 'category_l3','category_l4','category_l5','category_l6','category_l7','category_l8']] = targetted_keywords_category_score_V3['concat'].str.split(">", expand=True)

# %%
# Addition of column as per the given format
targetted_keywords_category_score_V3['sku_id'] = '20072024'

# Create a new column with trimmed and space-free keywords
# targetted_keywords_category_score_V2['trimmed_keyword'] = targetted_keywords_category_score_V2['text'].str.strip().str.replace(' ', '')

targetted_keywords_category_score_V3['count'] = targetted_keywords_category_score_V3['top_score']

targetted_keywords_category_score_V3['source'] = 'manual'
targetted_keywords_category_score_V3.columns
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_16252\2582213371.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targetted_keywords_category_score_V3['sku_id'] = '20072024'
# C:\Users\mayur\AppData\Local\Temp\ipykernel_16252\2582213371.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targetted_keywords_category_score_V3['count'] = targetted_keywords_category_score_V3['top_score']
# C:\Users\mayur\AppData\Local\Temp\ipykernel_16252\2582213371.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targetted_keywords_category_score_V3['source'] = 'manual'
# Index(['text', 'concat', 'trimmed_keyword', 'top_score', 'extracted_brand',
#        'category_l1', 'category_l2', 'category_l3', 'category_l4',
#        'category_l5', 'category_l6', 'category_l7', 'category_l8', 'sku_id',
#        'count', 'source'],
#       dtype='object')

# %%
targetted_keywords_category_score_V3 = targetted_keywords_category_score_V3.drop(['concat', 'extracted_brand'], axis=1)

# %%
targetted_keywords_category_score_V3.head()
# Out:
#                text trimmed_keyword  top_score category_l1 category_l2  \
# 0   8 oclock coffee   8oclockcoffee      375.0     grocery   beverages
# 1   8 oclock coffee   8oclockcoffee      375.0     grocery   beverages
# 9         air fryer        airfryer        7.5     grocery      frozen
# 10          alfredo         alfredo      240.0     grocery   beverages
# 11          alfredo         alfredo      240.0     grocery   beverages
#
#     category_l3     category_l4 category_l5 category_l6 category_l7  \
# 0        coffee        espresso         nan         nan         nan
# 1        coffee          ground         nan         nan         nan
# 9   frozen meat  frozen poultry         nan         nan         nan
# 10  drink mixes             nan         nan         nan         nan
# 11          tea           black         nan         nan         nan
#
#    category_l8    sku_id  count  source
# 0          nan  20072024  375.0  manual
# 1          nan  20072024  375.0  manual
# 9          nan  20072024    7.5  manual
# 10         nan  20072024  240.0  manual
# 11         nan  20072024  240.0  manual

# %%
targetted_keywords_category_score_V3.columns
# Out:
# Index(['text', 'trimmed_keyword', 'top_score', 'category_l1', 'category_l2',
#        'category_l3', 'category_l4', 'category_l5', 'category_l6',
#        'category_l7', 'category_l8', 'sku_id', 'count', 'source'],
#       dtype='object')

# %%
# targetted_keywords_category_score_V2['top_score'] = 
# Rearrange columns
desired_order = [
    'trimmed_keyword', 'text', 'sku_id', 'category_l1', 'category_l2', 'category_l3',
    'category_l4', 'category_l5', 'category_l6', 'category_l7', 'category_l8',
    'count', 'top_score', 'source'
]

targetted_keywords_category_score_V3 = targetted_keywords_category_score_V3[desired_order]
targetted_keywords_category_score_V3.head()
# Out:
#    trimmed_keyword             text    sku_id category_l1 category_l2  \
# 0    8oclockcoffee  8 oclock coffee  20072024     grocery   beverages
# 1    8oclockcoffee  8 oclock coffee  20072024     grocery   beverages
# 9         airfryer        air fryer  20072024     grocery      frozen
# 10         alfredo          alfredo  20072024     grocery   beverages
# 11         alfredo          alfredo  20072024     grocery   beverages
#
#     category_l3     category_l4 category_l5 category_l6 category_l7  \
# 0        coffee        espresso         nan         nan         nan
# 1        coffee          ground         nan         nan         nan
# 9   frozen meat  frozen poultry         nan         nan         nan
# 10  drink mixes             nan         nan         nan         nan
# 11          tea           black         nan         nan         nan
#
#    category_l8  count  top_score  source
# 0          nan  375.0      375.0  manual
# 1          nan  375.0      375.0  manual
# 9          nan    7.5        7.5  manual
# 10         nan  240.0      240.0  manual
# 11         nan  240.0      240.0  manual

# %%
targetted_keywords_category_score_V3[targetted_keywords_category_score_V3['text']=='salmon']
# Out:
#      trimmed_keyword    text    sku_id category_l1 category_l2  \
# 1626          salmon  salmon  20072024     grocery      frozen
# 1627          salmon  salmon  20072024     grocery      frozen
# 1628          salmon  salmon  20072024     grocery      frozen
#
#                category_l3      category_l4 category_l5 category_l6  \
# 1626  frozen meals & sides  seafood entrees         nan         nan
# 1627        frozen seafood             fish         nan         nan
# 1628        frozen seafood        shellfish         nan         nan
#
#      category_l7 category_l8   count  top_score  source
# 1626         nan         nan  1617.3     1617.3  manual
# 1627         nan         nan  1617.3     1617.3  manual
# 1628         nan         nan  1617.3     1617.3  manual

# %%
targetted_keywords_category_score_V3.tail()
# Out:
#          trimmed_keyword                text    sku_id category_l1  \
# 152127  zwanluncheonmeat  zwan luncheon meat  20072024     grocery
# 152128     çannédchicken      çannéd chicken  20072024     grocery
# 152129     çannédchicken      çannéd chicken  20072024     grocery
# 152130     çannédchicken      çannéd chicken  20072024     grocery
# 152131     çannédchicken      çannéd chicken  20072024     grocery
#
#                 category_l2               category_l3     category_l4  \
# 152127                 meat                  sausages    more sausage
# 152128  dietary & lifestyle                   organic            meat
# 152129               frozen               frozen meat  frozen poultry
# 152130                 meat  prepared & ready to heat             nan
# 152131                 meat                  sausages    more sausage
#
#        category_l5 category_l6 category_l7 category_l8  count  top_score  \
# 152127         nan         nan         nan         nan  500.0      500.0
# 152128         nan         nan         nan         nan  500.0      500.0
# 152129         nan         nan         nan         nan  500.0      500.0
# 152130         nan         nan         nan         nan  500.0      500.0
# 152131         nan         nan         nan         nan  500.0      500.0
#
#         source
# 152127  manual
# 152128  manual
# 152129  manual
# 152130  manual
# 152131  manual

# %%
# targetted_keywords_category_score_V2.to_csv("targetted_and_phrase_keyword_category_mapping_10008513(utf-8).csv", index=False, encoding='utf-8')

# %%
# Create an Excel writer object
excel_writer = pd.ExcelWriter('Targetted_and_phrase_keyword_category_mapping_395539(utf-8).xlsx', engine='xlsxwriter')

# Write each DataFrame to a separate sheet in the same Excel file
targetted_keywords_category_score_V3.to_excel(excel_writer, sheet_name='key_cat_mapping', index=False)

# Save the Excel file
excel_writer.save()
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_16252\2285148538.py:8: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   excel_writer.save()

# %%
total_keywords = pd.merge(targetted_keywords_category_score_V3, requests_df, left_on='text', right_on='keywords', how='left')
total_keywords.shape
# Out:
# (77294, 21)

# %%
print(total_keywords['request'].sum()), print(total_keywords['response'].sum())
# Out:
# 1128193.0
# 85774.0
# (None, None)

# %%
print(requests_df['request'].sum()), print(requests_df['response'].sum())
# Out:
# 3871458
# 1110709
# (None, None)

# %%
(85774.0/1128193.0)*100
# Out:
# 7.602777184400186

# %%
print(f"Our Keywords Contribution in requests {(total_keywords['request'].sum())/(requests_df['request'].sum())*100} and responses {(total_keywords['response'].sum())/(requests_df['res'].sum())*100}")
# Out:
# Our Keywords Contribution in requests 29.141295088310397 and responses 7.722454756376333
