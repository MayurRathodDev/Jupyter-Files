# %%
import pandas as pd
import numpy as np
from rapidfuzz import process, fuzz
import re
from tqdm import tqdm
from typing import Optional, Any, List, Tuple, Dict

# %%
# Keywords request response
requests_df = pd.read_csv("keywords_req&resp_163519(22-28July).csv")
requests_df.shape
# Out:
# (930730, 6)

# %%
requests_df.head()
# Out:
#                        trimmed_keyword  \
# 0                             lipstick
# 1  alpsgoodnessrosemarywaterrefillpack
# 2                            sunscreen
# 3                             facewash
# 4                           foundation
#
#                                    keywords  word_cnt  request  response  \
# 0                                  lipstick         1   213661    212057
# 1  alps goodness rosemary water refill pack         6    98715     24434
# 2                                 sunscreen         1    86398     86398
# 3                                 face wash         2    76316     76004
# 4                                foundation         1    61821     61821
#
#            RR
# 0   99.249278
# 1   24.752064
# 2  100.000000
# 3   99.591174
# 4  100.000000

# %%
# Keyword campaign level data
campaign_keywords = pd.read_csv("targetted_keywords_in_campaign_29July_163519.csv")
campaign_keywords.shape
# Out:
# (67335, 11)

# %%
# Cleaning & filtering the Data

# Step 1: Filter the data where is_negative is 'False'
filtered_df = campaign_keywords[campaign_keywords['is_negative'] == False]

# Step 2: Filter the data where status_type is 'ACTIVE'
filtered_df = filtered_df[filtered_df['status_type'] == 'ACTIVE']

# Step 3: Group by 'marketing_campaign_id' and 'text'
grouped_df = filtered_df.groupby(['keyword_id','marketing_campaign_id', 'text', 'match_type'], as_index=False).first()

# Step 4: Drop duplicate combinations (this is automatically handled by the groupby and first combination)
cleaned_camp_key_df = grouped_df.drop_duplicates(subset=['keyword_id','marketing_campaign_id', 'text', 'match_type'])

# %%
cleaned_camp_key_df.head()
# Out:
#    keyword_id  marketing_campaign_id           text match_type  \
# 0      135196                 375534     sheet mask     PHRASE
# 1      135197                 375534      face mask     PHRASE
# 2      135198                 375534    korean mask     PHRASE
# 3      135199                 375534           mask     PHRASE
# 4      389279                 551819  Pilgrim Serum      BROAD
#
#    marketplace_client_id  agency_id  is_negative status_type  bidding_value  \
# 0                 163519        122        False      ACTIVE           30.0
# 1                 163519        122        False      ACTIVE           25.0
# 2                 163519        122        False      ACTIVE           25.0
# 3                 163519        122        False      ACTIVE           25.0
# 4                 163519        122        False      ACTIVE           30.0
#
#   bidding_currency  bidding_value_usd
# 0              INR             0.4059
# 1              INR             0.3383
# 2              INR             0.3383
# 3              INR             0.3383
# 4              INR             0.4059

# %%
cleaned_camp_key_df.shape
# Out:
# (44974, 11)

# %%
campaign_keywords[campaign_keywords['status_type'] == "ACTIVE"]
# Out:
#        marketplace_client_id  agency_id  keyword_id  marketing_campaign_id  \
# 0                     163519        122     1268001                 245954
# 1                     163519        122     1268003                 245954
# 2                     163519        122     1268004                 245954
# 3                     163519        122     1268002                 245954
# 17                    163519        122     1265600                 290230
# ...                      ...        ...         ...                    ...
# 67330                 163519        122      769142                 668804
# 67331                 163519        122      769145                 668804
# 67332                 163519        122      756625                 668804
# 67333                 163519        122      769158                 668804
# 67334                 163519        122      769154                 668804
#
#                                       text  is_negative match_type  \
# 0                                face wash         True      EXACT
# 1                      vitamin c face wash         True      EXACT
# 2                               face scrub         True      EXACT
# 3                  face wash for oily skin         True      EXACT
# 17         best body wash for glowing skin         True      EXACT
# ...                                    ...          ...        ...
# 67330               best under eye patches        False      EXACT
# 67331         eye patches for dark circles        False      EXACT
# 67332  dark circle remover under eye patch        False      EXACT
# 67333                  cooling eye patches        False      EXACT
# 67334      under eye patches for puffiness        False      EXACT
#
#       status_type  bidding_value bidding_currency  bidding_value_usd
# 0          ACTIVE           0.00              NaN             0.0000
# 1          ACTIVE           0.00              NaN             0.0000
# 2          ACTIVE           0.00              NaN             0.0000
# 3          ACTIVE           0.00              NaN             0.0000
# 17         ACTIVE           0.00              NaN             0.0000
# ...           ...            ...              ...                ...
# 67330      ACTIVE          16.67              INR             0.2256
# 67331      ACTIVE          16.67              INR             0.2256
# 67332      ACTIVE          16.67              INR             0.2256
# 67333      ACTIVE          16.67              INR             0.2256
# 67334      ACTIVE          16.67              INR             0.2256
#
# [61909 rows x 11 columns]

# %% [markdown]
# ### Subset the data for keyword & match type

# %%
keyword_match_df = cleaned_camp_key_df[['text', 'match_type']]
keyword_match_df = keyword_match_df.drop_duplicates(subset=['text', 'match_type'])
keyword_match_df.shape
# Out:
# (31508, 2)

# %%
keyword_match_df.head()
# Out:
#             text match_type
# 0     sheet mask     PHRASE
# 1      face mask     PHRASE
# 2    korean mask     PHRASE
# 3           mask     PHRASE
# 4  Pilgrim Serum      BROAD

# %%
len(keyword_match_df['text'].unique())
# Out:
# 23865

# %%
# Filter out EXACT & Phrase match type keywords
exact_keywords_df = keyword_match_df[keyword_match_df['match_type']=="EXACT"]
phrase_keywords_df = keyword_match_df[keyword_match_df['match_type']=="PHRASE"]
broad_keywords_df = keyword_match_df[keyword_match_df['match_type']=="BROAD"]

# %%
print("Exact: ", exact_keywords_df.shape)
print("Phrase: ", phrase_keywords_df.shape)
print("Broad: ", broad_keywords_df.shape)  # broad 584, phrase 7, exact 413
# Out:
# Exact:  (16084, 2)
# Phrase:  (7571, 2)
# Broad:  (7853, 2)

# %%
broad_keywords_df.head()
# Out:
#                     text match_type
# 4          Pilgrim Serum      BROAD
# 14          the Ordinary      BROAD
# 15                 COSRX      BROAD
# 325           hair color      BROAD
# 326  garnier hair colour      BROAD

# %% [markdown]
# ### Exact Matching Handling

# %%
# For Exact we have to direct map the request volume
exact_keywords_req_df = pd.merge(exact_keywords_df, requests_df[['keywords', 'request', 'response', 'RR']], left_on='text', right_on='keywords', how='left')
print(exact_keywords_req_df.isnull().sum())
# exact_keywords_req_df = exact_keywords_req_df.drop('keywords', axis=1)
exact_keywords_req_df = exact_keywords_req_df.fillna(0)
# Out:
# text             0
# match_type       0
# keywords      4816
# request       4816
# response      4816
# RR            4816
# dtype: int64

# %%
exact_keywords_req_df.head(20)
# Out:
#                           text match_type                    keywords  \
# 0                   Minimalist      EXACT                           0
# 1                         Plum      EXACT                           0
# 2                        Serum      EXACT                           0
# 3                   Plum Serum      EXACT                           0
# 4                 henna powder      EXACT                henna powder
# 5                      mascara      EXACT                     mascara
# 6           mascara waterproof      EXACT          mascara waterproof
# 7            mascara for women      EXACT           mascara for women
# 8   maskara for eye waterproof      EXACT  maskara for eye waterproof
# 9                     lipstick      EXACT                    lipstick
# 10                   lipsticks      EXACT                   lipsticks
# 11             lipsticks matte      EXACT             lipsticks matte
# 12          lipstick for women      EXACT          lipstick for women
# 13         lipsticks for women      EXACT         lipsticks for women
# 14                    eyeliner      EXACT                    eyeliner
# 15                eyeliner pen      EXACT                eyeliner pen
# 16                   eye liner      EXACT                   eye liner
# 17                       kajal      EXACT                       kajal
# 18            kajal waterproof      EXACT            kajal waterproof
# 19                 kajal black      EXACT                 kajal black
#
#      request  response          RR
# 0        0.0       0.0    0.000000
# 1        0.0       0.0    0.000000
# 2        0.0       0.0    0.000000
# 3        0.0       0.0    0.000000
# 4     1499.0    1499.0  100.000000
# 5    19388.0   19334.0   99.721477
# 6    17487.0   17485.0   99.988563
# 7       12.0      12.0  100.000000
# 8        5.0       0.0    0.000000
# 9   213661.0  212057.0   99.249278
# 10    1803.0    1783.0   98.890738
# 11      21.0      21.0  100.000000
# 12      89.0      89.0  100.000000
# 13      21.0      21.0  100.000000
# 14   30907.0   30906.0   99.996764
# 15     351.0     351.0  100.000000
# 16    2267.0    2222.0   98.014998
# 17   23902.0   23850.0   99.782445
# 18   18564.0   18173.0   97.893773
# 19      33.0      33.0  100.000000

# %%
# Add one extra column as veriations, here we're renaming keyword to variations
exact_keywords_req_df.rename(columns={'keywords':'keyword_variation'}, inplace=True)

# %%
exact_keywords_req_df.tail()
# Out:
#                                      text match_type  \
# 16079         dermatouch kojic acid serum      EXACT
# 16080  simple hydrating light moisturizer      EXACT
# 16081         ponds hyaluronic acid serum      EXACT
# 16082                                Mist      EXACT
# 16083                           Body Mist      EXACT
#
#                         keyword_variation  request  response         RR
# 16079         dermatouch kojic acid serum    133.0     126.0  94.736842
# 16080  simple hydrating light moisturizer    140.0     136.0  97.142857
# 16081         ponds hyaluronic acid serum     94.0      92.0  97.872340
# 16082                                   0      0.0       0.0   0.000000
# 16083                                   0      0.0       0.0   0.000000

# %%
exact_keywords_req_df.shape
# Out:
# (16084, 6)

# %% [markdown]
# ### Phrase Matching Handling

# %%
# Handling the phrase variations by Extracting the phrase variation of phrase matched targetted keywords

# Function for the manipulations on the targeted keywords
def targeted_keywords_manipulation(targeted_keywords) -> pd.DataFrame:
    targeted_keywords["lower_tar_keyword"] = (targeted_keywords["text"].str.lower().str.strip())
    targeted_keywords = targeted_keywords.loc[(~(targeted_keywords["lower_tar_keyword"].isna())) & (targeted_keywords["lower_tar_keyword"] != "")]    
    return targeted_keywords.lower_tar_keyword

# Function for the manipulations on the search queries
def search_query_manipulation(search_queries)->Tuple[pd.DataFrame, List[str]]:
    search_queries["lower_search_keyword"] = search_queries["keywords"].str.lower().str.strip()
    search_query_df_v2 = (
        search_queries.groupby(["trimmed_keyword", "lower_search_keyword", "word_cnt"])
                                .agg({"request": "sum", "response": "sum"})
                                .reset_index()
                                .sort_values(by="request", ascending=False)
                                )

    phrase_df = search_query_df_v2.copy()
    phrase_df = phrase_df.rename(
                                columns={
                                    "lower_search_keyword": "phrase_keyword",
                                    "request": "phrase_request",
                                    "response": "phrase_response_cnt",
                                }
                                ).drop(columns=["trimmed_keyword", "word_cnt"])
    
    # Create a list with phrase candidates
    phrase_set_lst = phrase_df["phrase_keyword"].tolist()
    return phrase_df, phrase_set_lst

def find_phrase_variations(targetted_keywords: List[str], search_query: List[str], score_cutoff=100):
    targeted_query_len = len(targetted_keywords)
    
    # Filter phrases that contain the targeted keywords and are of equal or greater length
    filtered_phrase_set = [query for query in search_query if len(query) >= targeted_query_len and targetted_keywords in query]
    
    matches = process.extract(targetted_keywords, filtered_phrase_set, scorer=fuzz.token_set_ratio, limit=None)
    score_filtered_lst = [key for key, score, _ in matches if score == score_cutoff]
    
    return score_filtered_lst

# %%
cleaned_phrase_keywords = targeted_keywords_manipulation(phrase_keywords_df)
cleaned_phrase_keywords = pd.DataFrame(phrase_keywords_df) # dataset should be in dataframe
cleaned_phrase_keywords.head()
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_4104\3180134169.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targeted_keywords["lower_tar_keyword"] = (targeted_keywords["text"].str.lower().str.strip())
#           text match_type lower_tar_keyword
# 0   sheet mask     PHRASE        sheet mask
# 1    face mask     PHRASE         face mask
# 2  korean mask     PHRASE       korean mask
# 3         mask     PHRASE              mask
# 5   Face Serum     PHRASE        face serum

# %%
cleaned_phrase_keywords.shape
# Out:
# (7571, 3)

# %%
phrase_df, phrase_set_lst = search_query_manipulation(requests_df)
phrase_set_lst   # This has to be in series
# Out:
# ['lipstick',
#  'alps goodness rosemary water refill pack',
#  'sunscreen',
#  'face wash',
#  'foundation',
#  'dermdoc face serum',
#  'serum',
#  'lip balm',
#  'dermdoc underarm darkness',
#  'alps goodness rose water',
#  'shampoo',
#  'toner',
#  'rosemary',
#  'hair serum',
#  'rosemary water',
#  'concealer',
#  'face pack',
#  'eyeliner',
#  'body lotion',
#  'body wash',
#  'good vibes face wash',
#  'eyeshadow',
#  'maybelline lipstick',
#  'primer',
#  'ny bae pro strobe cream 3 in 1 foundation',
#  'faces canada foundation',
#  'cetaphil cleanser',
#  'lip gloss',
#  'mars lipstick',
#  'nail polish',
#  'alps goodness rosemary water',
#  'hair mask',
#  'moisturizer for face',
#  'mama earth face wash',
#  'kajal',
#  'eye liner waterproof',
#  'night cream',
#  'vitamin c face serum',
#  'compact',
#  'skincare',
#  'rose water',
#  'dot and key sunscreen',
#  'simple face wash',
#  'loreal shampoo',
#  'face moisturizer',
#  'face serum',
#  'dermdoc',
#  'niacinamide serum',
#  'conditioner',
#  'mascara',
#  'highlighter',
#  'swiss beauty lipstick',
#  'kajal waterproof',
#  'blush',
#  'ponds moisturizer',
#  'rosemary oil',
#  'cleanser',
#  'facial kit',
#  'alps goodness rosemary essential oil',
#  'dermdoc night cream',
#  'mascara waterproof',
#  'sunscreen spf 50',
#  'perfume for women',
#  'aqualogica sunscreen',
#  'dermdoc 5 glycolic acid underarm spray',
#  'lip liner',
#  'good vibes',
#  'cetaphil moisturizer',
#  'under eye cream for dark circles',
#  'ponds',
#  'strobe cream',
#  'dot and key skin care combo kit',
#  'sheet mask',
#  'good vibes night cream',
#  'makeup',
#  'sugar lipstick',
#  'alps goodness',
#  'lakme',
#  'hair care',
#  'maybelline fit me foundation',
#  'moisturizer',
#  'dot and key moisturizer',
#  'lip makeup',
#  'alps goodness beetroot powder',
#  'swiss beauty',
#  'good vibes ubtan powder',
#  'dr sheth sunscreen',
#  'plum serum',
#  'lip balm with spf',
#  'good vibes toner',
#  'ny bae',
#  'lakme sunscreen',
#  'perfume',
#  'lakme lipstick',
#  'streax hair serum',
#  'jewellery',
#  'insight lipstick',
#  'derma co sunscreen',
#  'mama earth lipstick',
#  'deconstruct sunscreen',
#  'ny bae lipstick',
#  'makeup setting spray',
#  'alps goodness rosemary water 200ml',
#  'face mask',
#  'eyebrow pencil',
#  'bb cream',
#  'minimalist serum',
#  'nude lipstick',
#  'plum toner',
#  'love beauty and planet shampoo',
#  'lakme compact powder',
#  'hair oil',
#  'scrub',
#  'golden peel off mask',
#  'alps goodness shampoo',
#  'loreal hair serum',
#  'ny bea foundation',
#  'dot and key face wash',
#  'lakme 9 to 5 cc cream',
#  'compact powder',
#  'ponds bb cream',
#  'eyeshadow palette',
#  'haircare',
#  'eye makeup',
#  'good vibes face serum',
#  'ponds super light gel moisturizer',
#  'aloe vera gel',
#  'mama earth sunscreen',
#  'plum',
#  'salicylic acid serum',
#  'minimalist',
#  'makeup kit',
#  'lip and cheek tints',
#  'maybelline',
#  'ponds facewash',
#  'wishcare lip balm',
#  'faces canada makeup fixer',
#  'bella vita perfume for women',
#  'blue heaven lipstick',
#  'mamaearth',
#  'aqualogica sunscreen and moisturizer combo',
#  'biotique face wash',
#  'renee kajal',
#  'forever 52 foundation',
#  'brush sets',
#  'hair colour',
#  'loreal paris conditioner',
#  'body scrub',
#  'lakme lumi lit cream moisturizer with highlighter',
#  'face scrub',
#  'lotus white glow cream',
#  'plum body mist',
#  'body mist',
#  'cetaphil face wash',
#  'mama earth shampoo',
#  'swiss beauty lip liner',
#  'fit me foundation',
#  'loreal shampoo and conditioner combo',
#  'multani mitti powder',
#  'ponds white beauty cream',
#  'derma doc night cream',
#  'rose mary water for hair growth',
#  'faces canada',
#  'ponds powder',
#  'plum face wash',
#  'faces canada strobe cream',
#  'beetroot powder',
#  'plum moisturizer',
#  'de tan face pack',
#  'ghar soaps magic soap',
#  'dermdoc sunscreen',
#  'minimalist sunscreen',
#  'rice water toner',
#  'nude shade lipstick',
#  'lakme eyeconic kajal',
#  'glycolic acid',
#  'lip scrub for dark lips',
#  'swiss beauty concealer',
#  'wishcare hair serum',
#  'liquid lipstick',
#  'himalaya neem face wash',
#  'blue heaven',
#  'carmesi facial razor',
#  'face cream',
#  'rose merry water spray',
#  'under arm roll on',
#  'ny bae strobe cream',
#  'dermodoc 2 kojic acid night cream',
#  'elle 18 lipstick',
#  'lakme peach milk moisturizer',
#  'lakme foundation',
#  'nail polish combo set',
#  'cosrx snail mucin',
#  'dove shampoo',
#  'maybelline fit me compact',
#  'pilgrim hair growth serum',
#  'biotique',
#  'derma co face wash',
#  'hair straightener',
#  'vaseline body lotion',
#  'makeup kits',
#  'mars eyeshadow palette',
#  'round lab',
#  'faces canada lipstick',
#  'hair growth serum',
#  'mars lip liner',
#  'makeup brush',
#  'skin care kit',
#  'lip tint',
#  'blusher and highlighter',
#  'charcoal peel off mask',
#  'nose strips for blackheads and whiteheads',
#  'hair spray',
#  'best skin whitening night cream',
#  'loose powder',
#  'garnier vitamin c serum',
#  'mama earth rosemary hair oil and shampoo combo',
#  'mars foundation',
#  'garnier face wash',
#  'good vibes day cream',
#  'eye brows palette',
#  'salicylic acid face wash',
#  'hair removal cream',
#  'dot key',
#  'derma co serum',
#  'be bodywise underarm roll on',
#  'mama earth moisturizer',
#  'dermdoc face wash',
#  'kojic acid serum',
#  'lakme face wash',
#  'insight concealer',
#  'lakme glycolic range',
#  'dermo doc underarm spray',
#  'o3 facial kit',
#  'toner for oily skin',
#  'plix rosemary hair growth serum',
#  'vaseline gluta hya',
#  '99 rs offer',
#  'tresemme shampoo',
#  'lakme absolute perfect radiance day cream',
#  'nail polish remover',
#  'livon hair serum',
#  'ponds face serum',
#  'lotus sunscreen',
#  'lakme forever matte liquid lipstick nude twist',
#  'alps',
#  'sugar foundation',
#  'alps goodness rosemary essential oil for hair growth',
#  'best sunscreen for oily skin',
#  'dot and key serum',
#  'moisturizer for oily skin',
#  'alps goodness facial kit',
#  'facewash',
#  'day cream',
#  'mars',
#  'perfume for men',
#  'lip liner pencil',
#  'maybelline mascara',
#  'ny bae kajal',
#  'b blunt shampoo',
#  'soap',
#  'lip scrub',
#  'matte lipstick',
#  'dove conditioner',
#  'vitamin c serum',
#  'garnier',
#  'retinol serum',
#  'swiss beauty primer',
#  'aqualogica moisturizer',
#  'good vibes face mask',
#  'all products under 99',
#  'mars lip gloss',
#  'alovera gel',
#  'ethiglo face wash',
#  'bella vita perfume',
#  'korean skin care products',
#  'wish care sunscreen body lotion',
#  'lotus face wash',
#  'b blunt shampoo and conditioner',
#  'lakme dew drama',
#  'rose mary water',
#  'face wash for oily skin',
#  'maybelline concealer',
#  'snail mucin',
#  'body wise salicylic acid body wash',
#  'himalaya face wash',
#  'apls goodness rosemary water',
#  'the ordinary niacinamide serum',
#  'de construct vitamin c',
#  'dove body wash',
#  'foxtale sunscreen',
#  'engage perfume for women',
#  'dot and key lip balm',
#  'plum lipstick',
#  'banana loose powder',
#  'insight',
#  'lotus',
#  'lakme eyeliner',
#  'eye shadow palette',
#  'cetaphil',
#  'sanfe instant tan dead skin removal',
#  'perfumes',
#  'hair brush',
#  'hair jewellery',
#  'accessory',
#  'mosturizer for face',
#  'lipstick combo set',
#  'foxtale',
#  'ny bae eyeliner',
#  'alps goodness rosemary',
#  'suncreen spf 50',
#  'insight primer',
#  'deconstruct serum',
#  'anti dandruff shampoo',
#  'dot and key',
#  'mac foundation',
#  'emolene moisturizer',
#  'renee lipstick',
#  'liquid blush',
#  'minimalist moisturizer',
#  'facial hair removal razor',
#  'nivea body lotion',
#  'alps goodness henna powder',
#  'mama earth lip balm',
#  'korean face mask sheets',
#  'pilgrim serum',
#  'nivea moisturizer',
#  'bath and body',
#  'biotique moisturizer',
#  'mama earth face cream',
#  'pimple patch',
#  'face powder',
#  'ponds natural glow face powder',
#  'renee midnight kohl kajal',
#  'dazler liquid lipstick dlco25',
#  'the ordinary glycolic acid toner',
#  'beauty blender',
#  'heat protection hair spray',
#  'lip mask',
#  'dr sheth moisturizer',
#  'dove',
#  'huda beauty foundation',
#  'love beauty and planet shampoo and conditioner',
#  'simple moisturizer',
#  'wishcare',
#  'makeup fixer',
#  'good vibes golden peal off mask',
#  'kurti for women dress',
#  'shower gel',
#  'loreal',
#  'good vibes ubtan de tan powder',
#  'aqualogica face wash',
#  'mama earth vitamin c daily glow face cream',
#  'wishcare sunscreen',
#  'ny bae 3 in 1 foundation',
#  'face razor for women',
#  'hair removal spray',
#  'alps goodness rosemary leaves',
#  'hair clip',
#  'wishcare underarm roll on',
#  'nail paint',
#  'hair scalp massager',
#  'hair',
#  'under eye serum',
#  'roll on',
#  'serum for face',
#  'pilgrim',
#  'loreal paris face serum',
#  'long lasting waterproof lipstick',
#  'contour',
#  'ubtan powder',
#  'eye brow pencil',
#  'garnier serum',
#  'matrix shampoo and conditioner',
#  'foxtale moisturizer',
#  'wish care aha bha body lotion',
#  'lux body wash',
#  'de construct sunscreen',
#  'sanfe',
#  'tan removal face pack',
#  'makeup remover',
#  'wish care hair growth serum',
#  'staze 9 to 9 lipstick',
#  'skin care gift',
#  'castor oil',
#  'khadi natural shampoo',
#  'good vibes lipstick',
#  'garnier micellar water',
#  'faces canada compact powder',
#  'lip stain',
#  'mars mascara',
#  'primer for oily skin',
#  'neutrogena sunscreen',
#  'face makeup',
#  'maybelline kajal',
#  'faces canada kajal',
#  'tinted sunscreen',
#  'hair dryer',
#  'plum sunscreen',
#  'cc cream',
#  'v wash',
#  'dot',
#  'maskara',
#  'pilgrim shampoo',
#  'alps goodness rosemary hair spray',
#  'swiss beauty eyeshadow palette',
#  'foundation brush',
#  'eye liner sketch pen',
#  'lip oil',
#  'rice water face wash',
#  'fix derma shadow sunscreen',
#  'fragrance',
#  'retinol night cream',
#  'my glam lipstick',
#  'venus razor for women',
#  'alps rossmarry water',
#  'alpsgoodness',
#  'good vibes de tan ubtan day cream',
#  'maybelline eyeliner',
#  'mac lipstick',
#  'ghar soap',
#  'indigo powder',
#  'coconut oil',
#  'brown lipstick',
#  'body scrub, polish',
#  'good vibes rosehip serum',
#  'lakme lumi cream',
#  'hair spa cream',
#  'carmesi under arm roll on',
#  'alphs goodness rosemary water',
#  'ny bea strobe cream and foundation combo',
#  'neem wooden comb',
#  'sugar pop lipstick',
#  'appliance',
#  'aqualogica',
#  'make up pouch bag',
#  'eyebrow enhancer',
#  'deconstruct vitamin c serum',
#  'ponds cream',
#  'lipbalm',
#  'lakme primer',
#  'acne removal',
#  'alps goodness rosemary water combo',
#  'insight blush',
#  'nivea roll on',
#  'dabur gulabari rose water',
#  'nivea lip balm',
#  'setting spray, powder',
#  'biotique shampoo',
#  'dermdoc 10 niacinamide face serum',
#  'derma co sali cinamide anti acne serum',
#  'white kajal',
#  'lip plumper',
#  'minimalist cleanser',
#  'lakme rose loose powder',
#  'naturali shampoo',
#  'mcaffeine',
#  'makeup pouch',
#  'mars lip crayon',
#  'stobe cream',
#  'lotus night cream',
#  'sugar pop',
#  'ny bea strobe cream',
#  'razor for women',
#  'sandalwood powder',
#  'everyuth scrub',
#  'insight colour corrector',
#  'dress',
#  'mama earth foundation',
#  'plum vitamin c serum',
#  'garnier cream',
#  'vaseline',
#  'moisturizer for dry skin',
#  'dr sheths',
#  'kojic acid',
#  'makeup set',
#  'cetaphil sunscreen',
#  'sugar',
#  'hair fall control shampoo',
#  'chemist at play underarm roll on',
#  'sunsilk shampoo',
#  'plum niacinamide serum',
#  'face wash for acne and pimples',
#  'under arms whitening roll on',
#  'ny bae makeup setting spray',
#  'swiss beauty makeup fixer',
#  'jovees face wash',
#  'rose marry water',
#  'rosemary leaves',
#  'wax strips',
#  'lakme 9 to 5 foundation',
#  'urban yog hair removal spray',
#  'namyaa intimate hygiene wash',
#  'adivasi hair oil',
#  'm caffeine body scrub',
#  'powder',
#  'face toner',
#  'biotique face toner',
#  'fiama shower gel',
#  'o3 de tan face pack',
#  'good vibes face scrub',
#  'deodorant for women',
#  'swiss beauty foundation',
#  'personal care',
#  'vaseline lip balm',
#  'hyaluronic acid serum',
#  'eye cream',
#  'facial massager',
#  'lotus facial kit',
#  'derma co moisturizer',
#  'renee perfume',
#  'veet hair removal cream',
#  'dot and key toner',
#  'eye mask',
#  'hand cream',
#  'pilgrim aha bha peeling solution',
#  'sugar kajal',
#  'swiss beauty eyeliner',
#  'kojic acid soap',
#  'good vibes sunscreen spf 50',
#  'night cream for skin brightening',
#  'dermdoc dark neck treatment',
#  'best face serum for glowing skin',
#  'mom',
#  'deconstruct lip balm',
#  'kurti set',
#  'hair accessory',
#  'hair setting spray for women',
#  'dermdoc kojic acid night cream',
#  'white tone powder',
#  'deodorant',
#  'demdoc under arm spray',
#  'carmesi pads',
#  'maybelline foundation',
#  'lipstick pallete',
#  'under eye patches',
#  'purito',
#  'loreal professionnel',
#  'hair care kit',
#  'sugar compact powder',
#  'hyphen lip balm',
#  'liquid sindoor',
#  'good vibes lip balm',
#  'tinted lip balm',
#  'lipstick combo',
#  'wax',
#  'blue heaven makeup kit combo',
#  'minimalist vitamin c serum',
#  'eye liner',
#  'blusher',
#  'derma co',
#  'faces canada 3 in 1 foundation',
#  'olay day cream',
#  'sanitary pads',
#  'plix serum',
#  'make up kit combo',
#  'glycolic acid serum',
#  'face tool',
#  'ponds face wash',
#  'female grooming',
#  'contour stick',
#  'plum body lotion',
#  'veet wax strips',
#  'menstrual cup',
#  'mama earth rice water face serum',
#  'red lipstick',
#  'toner for dry skin',
#  'sugar lip balm',
#  'makeup brushes',
#  'loreal paris glycolic bright face serum',
#  'deconstruct',
#  'cera ve cleanser',
#  'carmasi underarm roll on',
#  'dove soap',
#  'sunscreen stick',
#  'purple sunscreen',
#  'cotton pads for face',
#  'plum perfume',
#  'rosemary essential oil',
#  'combo',
#  'good vibes face moisturizer',
#  'baby care',
#  'alps rosemary water',
#  'mama earth face serum',
#  'under arms whitening cream',
#  'derma doc serum',
#  'indulekha hair oil',
#  'tan removal body scrub',
#  'wow face wash',
#  'eye care',
#  'renee',
#  'b blunt hair spa',
#  'face wash for dry skin',
#  'nivea face wash',
#  'sunscreen body lotion',
#  'face',
#  'good vibes charcoal peel off mask',
#  'tea tree essential oil',
#  'dove body scrub',
#  'sebamed lip balm',
#  'lakme 9 to 5 lipstick',
#  'pac foundation',
#  'good vibes gold peel off mask',
#  'ktein',
#  'plix',
#  'good vibes ubtan de tan night cream',
#  'pears body wash',
#  'fit me compact',
#  'swiss beauty blush',
#  'colour corrector',
#  'dove hair mask',
#  'lotus herbals',
#  'peel off mask',
#  'essential oil',
#  'derma doc sunscreen',
#  'good vibes sunscreen',
#  'plum rice water and niacinamide serum',
#  'tresemme conditioner',
#  'blue heaven lip balm',
#  'cetaphil cleanser for oily skin',
#  'bella vita perfume for men',
#  'kozicare soap',
#  'niacinamide',
#  'clean and clear face wash',
#  'skin care',
#  'cleansing oil',
#  'waterproof maskara',
#  'suncream',
#  'dazzler lipstick dlc025',
#  'lip balm for pigmented lips',
#  'foxtale serum',
#  '199 offer',
#  'dermadoc underarm spray',
#  'rice water',
#  'ice roller face',
#  'korean skincare',
#  'melalumin lip balm',
#  'nyka lipstick',
#  'nivea',
#  'alps goodness hair serum',
#  'derma co kojic acid serum',
#  'settings spray',
#  'oil free moisturizer',
#  'best perfumes for women',
#  'almond oil',
#  'carmesi period panty',
#  'clay mask',
#  'alps goodness indigo powder',
#  'blue heaven eyeliner',
#  'good vibes shampoo',
#  'ponds sunscreen',
#  'micellar water',
#  'tint',
#  'wet wipes for face',
#  'pilgrim moisturizer',
#  'mama earth onion hair oil',
#  'body wise underarm roll on',
#  'comb',
#  'miss claire lipstick',
#  'lotus herbals whiteglow skin whitening and brightening gel cream',
#  'gel eyeliner',
#  'cetaphil cleanser for oily skin face wash',
#  'eye lashes',
#  'cleansing brush',
#  'glutathione',
#  'conceler',
#  'joy face wash',
#  'curly hair products',
#  'alps goodness rose mary water',
#  'fiama soap',
#  'lakme face serum',
#  'b blunt hair mask',
#  'lakme cc cream',
#  'black head remover tool',
#  'facemakeup',
#  'hair extension',
#  'alps goodness facewash',
#  'castor oil for hair growth',
#  'under eye cream for dark circles dermdoc',
#  'face razor',
#  'nars foundation',
#  'face serum for dark spots and pigmentation',
#  'lipsticks',
#  'loreal paris',
#  'streax hair colour',
#  'neutrogena moisturizer',
#  'dr sheth face wash',
#  'namyaa intimate hair removal cream',
#  'cosrx',
#  'dry shampoo',
#  'neem powder',
#  'everteen sanitary pads',
#  'matrix shampoo',
#  'amla reetha shikakai powder alps goodness',
#  'good vibes papaya face wash',
#  'anti ageing cream',
#  'cream',
#  'good vibes face cream',
#  'loreal hair colour',
#  'serum for open pores',
#  'carmesi',
#  'wooden comb',
#  'mini lipstick',
#  'hair curler',
#  'face brush',
#  'facial razor',
#  'pedicure manicure kit',
#  'pigmentation cream',
#  'nose strips',
#  'face hair remover razor',
#  'alps goodness black henna powder',
#  'orange peel powder',
#  'orange colour corrector',
#  'kumkumadi face oil',
#  'darmdoc night cream',
#  'biotique sunscreen',
#  'sarees for women',
#  'just herbs mini lipstick combo',
#  'brush',
#  '99 store',
#  'swiss beauty lip gloss',
#  'loreal foundation',
#  'good vibes body lotion',
#  'lipgloss',
#  'mens face wash',
#  'skin whitening cream',
#  'renee black ph lipstick',
#  'mama earth ubtan face wash',
#  'minimalist salicylic acid face wash',
#  'lakme kajal',
#  'eye lashes curler',
#  'ny bae compact powder',
#  'biolage hair serum',
#  'maybelline superstay foundation',
#  'sexual wellness',
#  'maybelline new york super stay matte ink liquid lipstick',
#  'loreal hair spa cream',
#  'lakme forever matte liquid lipstick nude dream',
#  'lorial shampoo',
#  'plum body wash',
#  'skin brightening serum',
#  'biotique lip balm',
#  'makeup remover wipes',
#  'rire quick hair cara natural black',
#  'everyuth',
#  'good vibes skin care combo kit',
#  'nail art',
#  'bodywise',
#  'face mist',
#  'derma co vitamin c serum',
#  'loreal conditioner',
#  'pink lipstick',
#  'loreal paris hyaluronic acid hair night cream',
#  'lip crayon',
#  'livon',
#  'lakme 9 to 5 compact powder',
#  'makeup accessory',
#  'raaga de tan pack',
#  'bronzer',
#  'kay beauty lipstick',
#  'dermdoc face serum and night cream combo',
#  'beauty of joseon sunscreen',
#  'condom',
#  'body razor',
#  'brush set',
#  'body',
#  'simple',
#  'everyuth peel off mask',
#  'vlcc facial kit',
#  'deyga beetroot lip balm',
#  'primer for all skin type',
#  'ragaa d tan pack',
#  'pilgrim sunscreen spf 50',
#  'hair conditioner',
#  'the ordinary serum',
#  'alps goodness rosemary essential water spray',
#  'nail',
#  'the pink foundry acne spot',
#  'make up fixer spray',
#  'mac',
#  'eye shadow',
#  'golden face mask',
#  'henna powder',
#  'swiss beauty highlighter',
#  'mars girl power lipstick',
#  'makeup gift',
#  'love beauty and planet hair mask',
#  'concealer pallete',
#  'best sunscreen for dry skin',
#  'wax powder',
#  'nybae',
#  'black heads remover strips for nose',
#  'the derma co sunscreen',
#  'lacto calamine lotion',
#  'himalaya face serum',
#  'indulekha shampoo',
#  'mamaearth lipstick',
#  'mask',
#  'ear rings for women',
#  'wellness',
#  'makeup box',
#  'beetroot lip balm',
#  'm caffeine face wash',
#  'plum kajal',
#  'fair and lovely cream',
#  'artificial nail',
#  'epilator',
#  'simple refreshing face wash',
#  'carmesi bikini rasor',
#  'liquid highlighter',
#  'lakme absolute mousse foundation',
#  'nutriderm moisturizing lotion',
#  'leave in conditioner',
#  'body oil',
#  'acne pimple patch',
#  'sindoor',
#  'dazller lipstick',
#  'wish care lip balm',
#  'body spray',
#  'mama earth',
#  'plum skin care combo kit',
#  'wow aloe vera gel',
#  'dr sheths ceramide and vitamin c sunscreen',
#  'women dress',
#  'gua sha stone',
#  'parachute coconut oil',
#  'lakme sun expert sun',
#  'alps goodness hair shampoo and conditioner',
#  'purple lipstick',
#  'alps goodness beetroot powder face mask',
#  'neutriderm moisturizing lotion',
#  'french green clay powder',
#  'plum shampoo',
#  'intimate wash',
#  'mosturizer for oily skin',
#  'clinic plus shampoo',
#  'lakme day cream',
#  'huda beauty lipstick',
#  'lakme face powder',
#  'love beauty planet',
#  'diet',
#  'facial oil',
#  'mars bb cream',
#  'pixi blush stick',
#  'good vibes body wash',
#  'ny bae concealer',
#  'glutathione soap',
#  'olay night cream',
#  'biotique face scrub',
#  'derma roller for hair',
#  'dr seth sunscreen',
#  'bb',
#  'peel of mask',
#  'aha bha peeling solution',
#  'setting spray',
#  'blue heaven primer',
#  'ponds serum',
#  'wow shampoo',
#  'derm doc 10 niacinamide serum',
#  'love earth lipstick',
#  'multani mitti',
#  'woodoo hello clear skin face wash',
#  'dermdoc face cream',
#  'olay cream',
#  'good vibes ubtan insta glow powder',
#  'renee midnight kohl pencil',
#  'plum sunscreen spf 50',
#  'waxing strips',
#  'good vibes serum',
#  'elle 18 kajal',
#  'swiss beauty mascara',
#  'maybelline lipstick nude nuance',
#  'midnight kajal',
#  'nykaa lipstick',
#  'bleach',
#  'swiss beauty lip balm',
#  'ponds age miracle day cream',
#  'chemist at play body wash',
#  'dermaco',
#  'good vibes beetroot lip balm',
#  'makeup book',
#  'perfumed cream',
#  'alps goodness face wash',
#  'ny bae foundation',
#  'pilgrim lipstick',
#  'plam face serum',
#  'oriflame milk and honey scrub',
#  'chemist at play',
#  'lipliner',
#  'rose marry water for hair growth',
#  'the face shop rice water face wash',
#  'hair spa',
#  'make up blender sponge',
#  'renee sunscreen',
#  'good vibes vitamin c serum',
#  'de tan face wash',
#  'iba lipstick',
#  'layer wottagirl perfume',
#  'plum green tea night gel',
#  'minimalist niacinamide serum',
#  'dove shampoo and conditioner',
#  'nivea under arm roll on',
#  'cera ve moisturizer',
#  'carmesi body razor',
#  'derma',
#  'insight highlighter',
#  'charmacy milano foundation',
#  'intimate care',
#  'cuffs n lashes',
#  'pilgrim face wash',
#  'mama earth rice face wash',
#  'mama earth baby products',
#  'forever 52 concealer',
#  'bare anatomy shampoo',
#  'bblunt',
#  'envy perfume for women',
#  'dermdoc face moisturizer',
#  'fit me foundation 128',
#  'rose mary essential oil',
#  'aqualogica body mist',
#  'melalumin lip lightener',
#  'blue heaven mascara',
#  'plum body oil',
#  'shampoo for dry and frizzy hair',
#  'pads',
#  'eye primer',
#  'whisper sanitary pads',
#  'namyaa intimate wash',
#  '99 purple sale',
#  'vitamin c face wash',
#  'matrix hair serum',
#  'alps goodness powder',
#  'ethiglo soap',
#  'uv doux sunscreen',
#  'ny bae primer',
#  'glossy lipstick',
#  'ikonic hair straightener',
#  'flax seeds gel',
#  'aroma magic sunscreen',
#  'razor',
#  'dazzler lipstick',
#  'strex hair serum',
#  'staze lipstick',
#  'plum lip balm',
#  'good vibes eye kajal',
#  'ny bae pro strobe cream',
#  'gillette venus razor for women',
#  'cleansing milk',
#  'loreal paris dream length no hair cut cream',
#  'jojoba oil',
#  'pads for women',
#  'dr alies vitamin c serum',
#  'rose mary leaf',
#  'menstrual care',
#  'glycolic acid cream',
#  'round lab 1025 dokdo toner',
#  'the derma co serum',
#  'plum vanilla body mist',
#  '99',
#  'shaving',
#  'lakme cream',
#  'minimalist face wash',
#  'kojic acid cream',
#  'under eye cream',
#  'the face shop',
#  'full makeup kit',
#  'dot and key night cream',
#  'parfume for women',
#  'lipstick set',
#  'himalaya',
#  'foundation stick',
#  'loofah',
#  'faundation',
#  'insight lip and cheek tint',
#  'hypen products',
#  'darma doc face serum',
#  'pilgrim anti dandruff shampoo',
#  'vasline body lotion',
#  'makeup bag',
#  'glycerine',
#  'insight foundation',
#  'lakme absolute perfect radiance',
#  'lakme sunscreen spf 50',
#  'ny bea lipstick',
#  'philips hair straightener',
#  'aroma magic facial kit',
#  'loreal hair mask',
#  'himalaya shampoo',
#  'adivasi herbal hair oil',
#  'day and night face creams for glowing skin',
#  'kaja',
#  'baby skin care',
#  'face canada foundation',
#  'alps goodness black henna based hair colour',
#  'tresemme shampoo and conditioner combo',
#  'eye contact lenses',
#  'water proof lipstick',
#  'alps goodness conditioner',
#  'eye liner kajal and mascara combo',
#  'alpha arbutin serum',
#  ...]

# %%
# Finding Sub-queries
tqdm.pandas(desc="Finding the subqueries")
cleaned_phrase_keywords.loc[:, "matching_targets"] = cleaned_phrase_keywords["lower_tar_keyword"].progress_apply(lambda x: find_phrase_variations(x, phrase_set_lst))
cleaned_phrase_keywords
# Out:
# Finding the subqueries: 100%|██████████████████████████████████████████████████████| 7571/7571 [37:30<00:00,  3.36it/s]
#                                text match_type             lower_tar_keyword  \
# 0                        sheet mask     PHRASE                    sheet mask
# 1                         face mask     PHRASE                     face mask
# 2                       korean mask     PHRASE                   korean mask
# 3                              mask     PHRASE                          mask
# 5                        Face Serum     PHRASE                    face serum
# ...                             ...        ...                           ...
# 44851            Insight Foundation     PHRASE            insight foundation
# 44852  Insight Cosmetics foundation     PHRASE  insight cosmetics foundation
# 44853                    Foundation     PHRASE                    foundation
# 44971                          Mist     PHRASE                          mist
# 44972                     Body Mist     PHRASE                     body mist
#
#                                         matching_targets
# 0      [sheet mask, garnier sheet mask, good vibes sh...
# 1      [face mask, good vibes face mask, korean face ...
# 2      [korean mask, tomato korean mask, korean mask ...
# 3      [hair mask, sheet mask, face mask, golden peel...
# 5      [dermdoc face serum, vitamin c face serum, fac...
# ...                                                  ...
# 44851  [insight foundation, insight foundation hd, mn...
# 44852  [insight cosmetics foundation, insight cosmeti...
# 44853  [foundation, ny bae pro strobe cream 3 in 1 fo...
# 44971  [plum body mist, body mist, face mist, aqualog...
# 44972  [plum body mist, body mist, aqualogica body mi...
#
# [7571 rows x 4 columns]

# %%
# This line creates a new DataFrame filtered_df by filtering rows from cleaned_phrase_keywords where the matching_targets column is empty.
filtered_df = cleaned_phrase_keywords[cleaned_phrase_keywords["matching_targets"].apply(len) == 0]

phrase_matched_keywords = cleaned_phrase_keywords.explode("matching_targets")
print("Pre Shape: ", phrase_matched_keywords.shape)
phrase_matched_keywords = phrase_matched_keywords.drop_duplicates(subset=['lower_tar_keyword', 'matching_targets'])
print("Post Shape: ", phrase_matched_keywords.shape)
# Out:
# Pre Shape:  (1619590, 4)
# Post Shape:  (1241946, 4)

# %%
filtered_df.shape
# Out:
# (1560, 4)

# %%
phrase_matched_keywords.head()
# Out:
#          text match_type lower_tar_keyword       matching_targets
# 0  sheet mask     PHRASE        sheet mask             sheet mask
# 0  sheet mask     PHRASE        sheet mask     garnier sheet mask
# 0  sheet mask     PHRASE        sheet mask  good vibes sheet mask
# 0  sheet mask     PHRASE        sheet mask       sheet mask combo
# 0  sheet mask     PHRASE        sheet mask  lakme face sheet mask

# %%
# Adding request volume to phrase_matched_keywords
phrase_matched_keywords = pd.merge(phrase_matched_keywords, phrase_df[["phrase_keyword", "phrase_request", "phrase_response_cnt"]], how="inner", left_on="matching_targets", right_on="phrase_keyword")
phrase_matched_keywords = phrase_matched_keywords.drop('phrase_keyword', axis=1)
phrase_matched_keywords['phrase_response_rate'] = phrase_matched_keywords['phrase_response_cnt']*100/ phrase_matched_keywords['phrase_request']
phrase_matched_keywords.head()
# Out:
#          text match_type lower_tar_keyword    matching_targets  \
# 0  sheet mask     PHRASE        sheet mask          sheet mask
# 1        mask     PHRASE              mask          sheet mask
# 2  sheet mask     PHRASE        sheet mask  garnier sheet mask
# 3        mask     PHRASE              mask  garnier sheet mask
# 4     garnier     PHRASE           garnier  garnier sheet mask
#
#    phrase_request  phrase_response_cnt  phrase_response_rate
# 0           14900                14854             99.691275
# 1           14900                14854             99.691275
# 2            1069                  406             37.979420
# 3            1069                  406             37.979420
# 4            1069                  406             37.979420

# %%
phrase_matched_keywords[phrase_matched_keywords['text']=='bathing powder']
# Out:
#                    text match_type lower_tar_keyword  \
# 810011   bathing powder     PHRASE    bathing powder
# 842312   bathing powder     PHRASE    bathing powder
# 938124   bathing powder     PHRASE    bathing powder
# 953633   bathing powder     PHRASE    bathing powder
# 956318   bathing powder     PHRASE    bathing powder
# 1225079  bathing powder     PHRASE    bathing powder
# 1225226  bathing powder     PHRASE    bathing powder
# 1227040  bathing powder     PHRASE    bathing powder
# 1227182  bathing powder     PHRASE    bathing powder
# 1227948  bathing powder     PHRASE    bathing powder
# 1230349  bathing powder     PHRASE    bathing powder
# 1230351  bathing powder     PHRASE    bathing powder
# 1234265  bathing powder     PHRASE    bathing powder
# 1235723  bathing powder     PHRASE    bathing powder
#
#                         matching_targets  phrase_request  phrase_response_cnt  \
# 810011          mamaearth bathing powder               4                    0
# 842312         good vibes bathing powder              38                   34
# 938124      alps goodness bathing powder               2                    2
# 953633               body bathing powder               2                    0
# 956318     bathing powder body whitening               1                    0
# 1225079                   bathing powder              21                    0
# 1225226            herbal bathing powder              15                    2
# 1227040              baby bathing powder               4                    0
# 1227182     bathing powder for baby girl               4                    0
# 1227948  magnum wood girl bathing powder               2                    0
# 1230349     evevin herbal bathing powder               2                    0
# 1230351            evevin bathing powder               2                    0
# 1234265            shubra bathing powder               1                    0
# 1235723    herbal bathing powder for men               1                    0
#
#          phrase_response_rate
# 810011               0.000000
# 842312              89.473684
# 938124             100.000000
# 953633               0.000000
# 956318               0.000000
# 1225079              0.000000
# 1225226             13.333333
# 1227040              0.000000
# 1227182              0.000000
# 1227948              0.000000
# 1230349              0.000000
# 1230351              0.000000
# 1234265              0.000000
# 1235723              0.000000

# %%
phrase_matched_keywords = phrase_matched_keywords.drop('lower_tar_keyword', axis=1)
phrase_matched_keywords.rename(columns={'matching_targets':'keyword_variation',
                                        'phrase_request':'request',
                                        'phrase_response_cnt':'response',
                                         'phrase_response_rate':'RR'}, inplace=True)

# %%
phrase_matched_keywords[phrase_matched_keywords['text']=='bathing powder']
# Out:
#                    text match_type                keyword_variation  request  \
# 810011   bathing powder     PHRASE         mamaearth bathing powder        4
# 842312   bathing powder     PHRASE        good vibes bathing powder       38
# 938124   bathing powder     PHRASE     alps goodness bathing powder        2
# 953633   bathing powder     PHRASE              body bathing powder        2
# 956318   bathing powder     PHRASE    bathing powder body whitening        1
# 1225079  bathing powder     PHRASE                   bathing powder       21
# 1225226  bathing powder     PHRASE            herbal bathing powder       15
# 1227040  bathing powder     PHRASE              baby bathing powder        4
# 1227182  bathing powder     PHRASE     bathing powder for baby girl        4
# 1227948  bathing powder     PHRASE  magnum wood girl bathing powder        2
# 1230349  bathing powder     PHRASE     evevin herbal bathing powder        2
# 1230351  bathing powder     PHRASE            evevin bathing powder        2
# 1234265  bathing powder     PHRASE            shubra bathing powder        1
# 1235723  bathing powder     PHRASE    herbal bathing powder for men        1
#
#          response          RR
# 810011          0    0.000000
# 842312         34   89.473684
# 938124          2  100.000000
# 953633          0    0.000000
# 956318          0    0.000000
# 1225079         0    0.000000
# 1225226         2   13.333333
# 1227040         0    0.000000
# 1227182         0    0.000000
# 1227948         0    0.000000
# 1230349         0    0.000000
# 1230351         0    0.000000
# 1234265         0    0.000000
# 1235723         0    0.000000

# %%
phrase_matched_keywords[phrase_matched_keywords['text']=='bathing powder']['request'].sum()
# Out:
# 99

# %%
phrase_matched_keywords.to_csv("phrase_testing_163519.csv", index=False)

# %%
# phrase_keywords_req_df = (phrase_matched_keywords.groupby(['text', 'match_type'])
#                                 .agg({"phrase_request": "sum", "phrase_response_cnt": "sum"})
#                                 .reset_index()
#                                 .sort_values(by="phrase_request", ascending=False))

# %%
# phrase_keywords_req_df.head()

# %%
# phrase_keywords_req_df.shape

# %%
# phrase_keywords_req_df[phrase_keywords_req_df['text']=='heineken']

# %%
# # Renaming the phrase keyword request and response columns
# phrase_keywords_req_df = phrase_keywords_req_df.rename(columns={"phrase_request": "request", "phrase_response_cnt": "response"})
# phrase_keywords_req_df['RR'] = phrase_keywords_req_df['response']*100/phrase_keywords_req_df['request']

# %% [markdown]
# ### Handling Broad match type

# %%
broad_keywords_df.head()
# Out:
#                     text match_type
# 4          Pilgrim Serum      BROAD
# 14          the Ordinary      BROAD
# 15                 COSRX      BROAD
# 325           hair color      BROAD
# 326  garnier hair colour      BROAD

# %%
broad_keywords_df.shape
# Out:
# (7853, 3)

# %%
# Function for the manipulations on the targeted keywords
def targeted_keywords_manipulation(targeted_keywords) -> pd.DataFrame:
    targeted_keywords["lower_tar_keyword"] = (targeted_keywords["text"].str.lower().str.strip())
    targeted_keywords = targeted_keywords.loc[(~(targeted_keywords["lower_tar_keyword"].isna())) & (targeted_keywords["lower_tar_keyword"] != "")]    
    return targeted_keywords.lower_tar_keyword

def find_complete_broad_variations(targeted_query: str, broad_set_lst: List[str], score_cutoff=100):
    # Split the targeted query into individual words
    targeted_query_split = targeted_query.lower().split()
    targeted_query_len = len(targeted_query)

    # Filter phrases that are equal or longer than the targeted query and contain all words from the targeted query
    filtered_broad_set = [
        broad for broad in broad_set_lst
        if len(broad) >= targeted_query_len and all(word in broad.lower() for word in targeted_query_split)
    ]

    # Perform fuzzy matching and filter based on the score cutoff
    matches = process.extract(targeted_query, filtered_broad_set, scorer=fuzz.token_set_ratio, limit=None)
    score_filtered_lst = [key for key, score, _ in matches if score == score_cutoff]
    
    return score_filtered_lst

# %%
# #apply filter of word lenth greateer than clilent length 
# def find_complete_broad_variations(targeted_query: List[str], broad_set_lst: List[str], score_cutoff=100):
#     # Split the targeted query into individual words
#     #print("targeted_query:", targeted_query)
#     targeted_query_split = targeted_query.lower().split()
#     #print("targeted_query_split: ", targeted_query_split)
    
#     # Filter phrases that contain all words from the targeted query and perform fuzzy matching
#     filtered_broad_set = [
#         broad for broad in broad_set_lst
#         if all(word in broad.lower() for word in targeted_query_split)
#     ]
#     #print("filtered_broad_set: ", filtered_broad_set)
    
#     # Perform fuzzy matching and filter based on the score cutoff
#     matches = process.extract(targeted_query, filtered_broad_set, scorer=fuzz.token_set_ratio, limit=None)
#     score_filtered_lst = [key for key, score, _ in matches if score == score_cutoff]
    
#     return score_filtered_lst

# %%
cleaned_broad_keywords = targeted_keywords_manipulation(broad_keywords_df)
cleaned_broad_keywords = pd.DataFrame(broad_keywords_df) # dataset should be in dataframe
cleaned_broad_keywords.head()
# Out:
#                     text match_type    lower_tar_keyword
# 4          Pilgrim Serum      BROAD        pilgrim serum
# 14          the Ordinary      BROAD         the ordinary
# 15                 COSRX      BROAD                cosrx
# 325           hair color      BROAD           hair color
# 326  garnier hair colour      BROAD  garnier hair colour

# %%
# Finding Sub-queries
#broad_set_2 = broad_set.head(5)
tqdm.pandas(desc="Finding the subqueries")
cleaned_broad_keywords.loc[:, "matching_targets"] = cleaned_broad_keywords["lower_tar_keyword"].progress_apply(lambda x: find_complete_broad_variations(x, phrase_set_lst))
cleaned_broad_keywords.head()
# Out:
# Finding the subqueries: 100%|████████████████████████████████████████████████████| 7853/7853 [2:16:21<00:00,  1.04s/it]
#                     text match_type    lower_tar_keyword  \
# 4          Pilgrim Serum      BROAD        pilgrim serum
# 14          the Ordinary      BROAD         the ordinary
# 15                 COSRX      BROAD                cosrx
# 325           hair color      BROAD           hair color
# 326  garnier hair colour      BROAD  garnier hair colour
#
#                                       matching_targets
# 4    [pilgrim hair growth serum, pilgrim serum, pil...
# 14   [the ordinary niacinamide serum, the ordinary ...
# 15   [cosrx snail mucin, cosrx, cosrx advanced snai...
# 325  [hair color, b blunt hair color, iba halal hai...
# 326  [garnier hair colour, garnier hair colour natu...

# %%
filtered_broad_df = cleaned_broad_keywords[cleaned_broad_keywords["matching_targets"].apply(len) == 0]

broad_matched_keywords = cleaned_broad_keywords.explode("matching_targets")
print("Pre Shape: ", broad_matched_keywords.shape)
broad_matched_keywords = broad_matched_keywords.drop_duplicates(subset=['lower_tar_keyword', 'matching_targets'])
print("Post Shape: ", broad_matched_keywords.shape)
# Out:
# Pre Shape:  (1740890, 4)
# Post Shape:  (1649492, 4)

# %%
broad_matched_keywords.head()
# Out:
#             text match_type lower_tar_keyword           matching_targets
# 4  Pilgrim Serum      BROAD     pilgrim serum  pilgrim hair growth serum
# 4  Pilgrim Serum      BROAD     pilgrim serum              pilgrim serum
# 4  Pilgrim Serum      BROAD     pilgrim serum         pilgrim face serum
# 4  Pilgrim Serum      BROAD     pilgrim serum         pilgrim hair serum
# 4  Pilgrim Serum      BROAD     pilgrim serum     pilgrim 24k gold serum

# %%
phrase_df.head()
# Out:
#                                   phrase_keyword  phrase_request  \
# 496808                                  lipstick          213661
# 42435   alps goodness rosemary water refill pack           98715
# 844631                                 sunscreen           86398
# 293207                                 face wash           76316
# 316130                                foundation           61821
#
#         phrase_response_cnt
# 496808               212057
# 42435                 24434
# 844631                86398
# 293207                76004
# 316130                61821

# %%
# Adding request volume to phrase_matched_keywords
broad_matched_keywords = pd.merge(broad_matched_keywords, phrase_df[["phrase_keyword", "phrase_request", "phrase_response_cnt"]], how="inner", left_on="matching_targets", right_on="phrase_keyword")
broad_matched_keywords = broad_matched_keywords.drop('phrase_keyword', axis=1)
broad_matched_keywords['phrase_response_rate'] = broad_matched_keywords['phrase_response_cnt']*100/ broad_matched_keywords['phrase_request']
broad_matched_keywords.head()
# Out:
#                         text match_type          lower_tar_keyword  \
# 0              Pilgrim Serum      BROAD              pilgrim serum
# 1                 hair serum      BROAD                 hair serum
# 2  pilgrim hair growth serum      BROAD  pilgrim hair growth serum
# 3         pilgrim hair serum      BROAD         pilgrim hair serum
# 4          hair growth serum      BROAD          hair growth serum
#
#             matching_targets  phrase_request  phrase_response_cnt  \
# 0  pilgrim hair growth serum            6228                 6022
# 1  pilgrim hair growth serum            6228                 6022
# 2  pilgrim hair growth serum            6228                 6022
# 3  pilgrim hair growth serum            6228                 6022
# 4  pilgrim hair growth serum            6228                 6022
#
#    phrase_response_rate
# 0             96.692357
# 1             96.692357
# 2             96.692357
# 3             96.692357
# 4             96.692357

# %%
broad_matched_keywords[broad_matched_keywords['text']=='hair serum']
# Out:
#               text match_type                   keyword_variation  request  \
# 1       hair serum      BROAD           pilgrim hair growth serum     6228
# 22      hair serum      BROAD                  pilgrim hair serum      460
# 36      hair serum      BROAD  pilgrim advanced hair growth serum      216
# 100     hair serum      BROAD        pilgrim anti grey hair serum       89
# 235     hair serum      BROAD                  pilgrim serum hair       21
# ...            ...        ...                                 ...      ...
# 478548  hair serum      BROAD                    elive hair serum        1
# 478552  hair serum      BROAD                    elosi serum hair        1
# 478556  hair serum      BROAD            else goodness hair serum        1
# 478561  hair serum      BROAD    nirwasha hair fall control serum        1
# 478569  hair serum      BROAD                    eeloe hair serum        1
#
#         response          RR
# 1           6022   96.692357
# 22           451   98.043478
# 36           209   96.759259
# 100           89  100.000000
# 235           21  100.000000
# ...          ...         ...
# 478548         0    0.000000
# 478552         0    0.000000
# 478556         1  100.000000
# 478561         0    0.000000
# 478569         0    0.000000
#
# [4865 rows x 6 columns]

# %%
broad_matched_keywords = broad_matched_keywords.drop('lower_tar_keyword', axis=1)
broad_matched_keywords.rename(columns={'matching_targets':'keyword_variation',
                                        'phrase_request':'request',
                                        'phrase_response_cnt':'response',
                                         'phrase_response_rate':'RR'}, inplace=True)

# %%
broad_matched_keywords[broad_matched_keywords['text']=='hair serum']['request'].sum()
# Out:
# 140182

# %%
broad_matched_keywords.to_csv("broad_testing_163519.csv", index=False)

# %%
exact_keywords_req_df.head()
# Out:
#            text match_type keyword_variation  request  response     RR
# 0    Minimalist      EXACT                 0      0.0       0.0    0.0
# 1          Plum      EXACT                 0      0.0       0.0    0.0
# 2         Serum      EXACT                 0      0.0       0.0    0.0
# 3    Plum Serum      EXACT                 0      0.0       0.0    0.0
# 4  henna powder      EXACT      henna powder   1499.0    1499.0  100.0

# %%
phrase_matched_keywords = pd.read_csv("phrase_testing_163519.csv")
broad_matched_keywords = pd.read_csv("broad_testing_163519.csv")

# %%
phrase_matched_keywords.head()
# Out:
#          text match_type   keyword_variation  request  response         RR
# 0  sheet mask     PHRASE          sheet mask    14900     14854  99.691275
# 1        mask     PHRASE          sheet mask    14900     14854  99.691275
# 2  sheet mask     PHRASE  garnier sheet mask     1069       406  37.979420
# 3        mask     PHRASE  garnier sheet mask     1069       406  37.979420
# 4     garnier     PHRASE  garnier sheet mask     1069       406  37.979420

# %% [markdown]
# ### Combining all match type requests and responses in single dataframe

# %%
# combining all match types keywords
combined_keyword_match_df = pd.concat([exact_keywords_req_df, phrase_matched_keywords, broad_matched_keywords], axis=0, ignore_index=True)
combined_keyword_match_df.shape
# Out:
# (2905472, 6)

# %% [raw]
# **Need to check the keyword numbers**

# %%
combined_keyword_match_df.head()
# Out:
#            text match_type keyword_variation  request  response     RR
# 0    Minimalist      EXACT                 0      0.0       0.0    0.0
# 1          Plum      EXACT                 0      0.0       0.0    0.0
# 2         Serum      EXACT                 0      0.0       0.0    0.0
# 3    Plum Serum      EXACT                 0      0.0       0.0    0.0
# 4  henna powder      EXACT      henna powder   1499.0    1499.0  100.0

# %%
combined_keyword_match_df.isnull().sum()
# Out:
# text                 0
# match_type           0
# keyword_variation    0
# request              0
# response             0
# RR                   0
# dtype: int64

# %%
combined_keyword_match_df.dtypes
# Out:
# text                  object
# match_type            object
# keyword_variation     object
# request              float64
# response             float64
# RR                   float64
# dtype: object

# %%
combined_keyword_match_df[combined_keyword_match_df['text']=='bathing powder']
# Out:
#                    text match_type                keyword_variation  request  \
# 826095   bathing powder     PHRASE         mamaearth bathing powder      4.0
# 858396   bathing powder     PHRASE        good vibes bathing powder     38.0
# 954208   bathing powder     PHRASE     alps goodness bathing powder      2.0
# 969717   bathing powder     PHRASE              body bathing powder      2.0
# 972402   bathing powder     PHRASE    bathing powder body whitening      1.0
# 1241163  bathing powder     PHRASE                   bathing powder     21.0
# 1241310  bathing powder     PHRASE            herbal bathing powder     15.0
# 1243124  bathing powder     PHRASE              baby bathing powder      4.0
# 1243266  bathing powder     PHRASE     bathing powder for baby girl      4.0
# 1244032  bathing powder     PHRASE  magnum wood girl bathing powder      2.0
# 1246433  bathing powder     PHRASE     evevin herbal bathing powder      2.0
# 1246435  bathing powder     PHRASE            evevin bathing powder      2.0
# 1250349  bathing powder     PHRASE            shubra bathing powder      1.0
# 1251807  bathing powder     PHRASE    herbal bathing powder for men      1.0
#
#          response          RR
# 826095        0.0    0.000000
# 858396       34.0   89.473684
# 954208        2.0  100.000000
# 969717        0.0    0.000000
# 972402        0.0    0.000000
# 1241163       0.0    0.000000
# 1241310       2.0   13.333333
# 1243124       0.0    0.000000
# 1243266       0.0    0.000000
# 1244032       0.0    0.000000
# 1246433       0.0    0.000000
# 1246435       0.0    0.000000
# 1250349       0.0    0.000000
# 1251807       0.0    0.000000

# %%
combined_keyword_match_df.head()
# Out:
#            text match_type keyword_variation  request  response     RR
# 0    Minimalist      EXACT                 0      0.0       0.0    0.0
# 1          Plum      EXACT                 0      0.0       0.0    0.0
# 2         Serum      EXACT                 0      0.0       0.0    0.0
# 3    Plum Serum      EXACT                 0      0.0       0.0    0.0
# 4  henna powder      EXACT      henna powder   1499.0    1499.0  100.0

# %%
cleaned_camp_key_df.head()
# Out:
#    keyword_id  marketing_campaign_id           text match_type  \
# 0      135196                 375534     sheet mask     PHRASE
# 1      135197                 375534      face mask     PHRASE
# 2      135198                 375534    korean mask     PHRASE
# 3      135199                 375534           mask     PHRASE
# 4      389279                 551819  Pilgrim Serum      BROAD
#
#    marketplace_client_id  agency_id  is_negative status_type  bidding_value  \
# 0                 163519        122        False      ACTIVE           30.0
# 1                 163519        122        False      ACTIVE           25.0
# 2                 163519        122        False      ACTIVE           25.0
# 3                 163519        122        False      ACTIVE           25.0
# 4                 163519        122        False      ACTIVE           30.0
#
#   bidding_currency  bidding_value_usd
# 0              INR             0.4059
# 1              INR             0.3383
# 2              INR             0.3383
# 3              INR             0.3383
# 4              INR             0.4059

# %%
combined_keyword_match_df.head()
# Out:
#            text match_type keyword_variation  request  response     RR
# 0    Minimalist      EXACT                 0      0.0       0.0    0.0
# 1          Plum      EXACT                 0      0.0       0.0    0.0
# 2         Serum      EXACT                 0      0.0       0.0    0.0
# 3    Plum Serum      EXACT                 0      0.0       0.0    0.0
# 4  henna powder      EXACT      henna powder   1499.0    1499.0  100.0

# %% [markdown]
# ### Merging campaigns and its targetted keywords with request tags based on Match types

# %%
combined_camp_keyword_match_df = pd.merge(cleaned_camp_key_df, combined_keyword_match_df, on=['text', 'match_type'], how='left')
combined_camp_keyword_match_df.shape
# Out:
# (9979768, 15)

# %%
combined_camp_keyword_match_df.isnull().sum()
# Out:
# keyword_id                  0
# marketing_campaign_id       0
# text                        0
# match_type                  0
# marketplace_client_id       0
# agency_id                   0
# is_negative                 0
# status_type                 0
# bidding_value               0
# bidding_currency            0
# bidding_value_usd           0
# keyword_variation        2337
# request                  2337
# response                 2337
# RR                       2337
# dtype: int64

# %%
# Need to focus on this as why this values are null one guess is these keywords has no request in last 7 days.
combined_camp_keyword_match_df[combined_camp_keyword_match_df.isnull().any(axis=1)]
# Out:
#          keyword_id  marketing_campaign_id                      text  \
# 83773        392656                 554912     sonic facial cleanser
# 103689       392688                 554919                face serum
# 103690       392689                 554919                    serums
# 146967       392693                 554919         niacinamide serum
# 147170       392697                 554919          minimalist serum
# ...             ...                    ...                       ...
# 9919906     1611618                 792271  pigmentation lipbalm spf
# 9950472     1620995                 771740                   Insight
# 9954398     1621001                 771740                 Concealer
# 9954437     1621020                 866346                Foundation
# 9979766     1628935                 867685                 Body Mist
#
#         match_type  marketplace_client_id  agency_id  is_negative status_type  \
# 83773       PHRASE                 163519        122        False      ACTIVE
# 103689      PHRASE                 163519        122        False      ACTIVE
# 103690      PHRASE                 163519        122        False      ACTIVE
# 146967      PHRASE                 163519        122        False      ACTIVE
# 147170      PHRASE                 163519        122        False      ACTIVE
# ...            ...                    ...        ...          ...         ...
# 9919906     PHRASE                 163519        122        False      ACTIVE
# 9950472     PHRASE                 163519        122        False      ACTIVE
# 9954398      BROAD                 163519        122        False      ACTIVE
# 9954437     PHRASE                 163519        122        False      ACTIVE
# 9979766     PHRASE                 163519        122        False      ACTIVE
#
#          bidding_value bidding_currency  bidding_value_usd keyword_variation  \
# 83773            25.00              INR             0.3383               NaN
# 103689           30.00              INR             0.4059               NaN
# 103690           30.00              INR             0.4059               NaN
# 146967           30.00              INR             0.4059               NaN
# 147170           30.00              INR             0.4059               NaN
# ...                ...              ...                ...               ...
# 9919906           7.00              INR             0.0947               NaN
# 9950472          15.00              INR             0.2030               NaN
# 9954398          23.00              INR             0.3112               NaN
# 9954437          20.00              INR             0.2706               NaN
# 9979766          70.89              INR             0.9592               NaN
#
#          request  response  RR
# 83773        NaN       NaN NaN
# 103689       NaN       NaN NaN
# 103690       NaN       NaN NaN
# 146967       NaN       NaN NaN
# 147170       NaN       NaN NaN
# ...          ...       ...  ..
# 9919906      NaN       NaN NaN
# 9950472      NaN       NaN NaN
# 9954398      NaN       NaN NaN
# 9954437      NaN       NaN NaN
# 9979766      NaN       NaN NaN
#
# [2337 rows x 15 columns]

# %%
combined_camp_keyword_match_df = combined_camp_keyword_match_df.fillna('0')

# %%
combined_camp_keyword_match_df.dtypes
# Out:
# keyword_id                 int64
# marketing_campaign_id      int64
# text                      object
# match_type                object
# marketplace_client_id      int64
# agency_id                  int64
# is_negative                 bool
# status_type               object
# bidding_value            float64
# bidding_currency          object
# bidding_value_usd        float64
# keyword_variation         object
# request                   object
# response                  object
# RR                        object
# dtype: object

# %%
# # Function to determine the tag based on the number of requests
# def get_reach_tag(requests):
#     if requests < 10:
#         return 'Very low Reach'
#     elif 10 <= requests < 100:
#         return 'Low Reach'
#     elif 100 <= requests < 1000:
#         return 'Moderate Reach'
#     else:
#         return 'High Reach'

# tagged_camp_key_df[['request', 'response', 'RR']] = tagged_camp_key_df[['request', 'response', 'RR']].astype(int)
# tagged_camp_key_df['reach_tag'] = tagged_camp_key_df['request'].apply(get_reach_tag)

# %%
combined_camp_keyword_match_df.head()
# Out:
#    keyword_id  marketing_campaign_id        text match_type  \
# 0      135196                 375534  sheet mask     PHRASE
# 1      135196                 375534  sheet mask     PHRASE
# 2      135196                 375534  sheet mask     PHRASE
# 3      135196                 375534  sheet mask     PHRASE
# 4      135196                 375534  sheet mask     PHRASE
#
#    marketplace_client_id  agency_id  is_negative status_type  bidding_value  \
# 0                 163519        122        False      ACTIVE           30.0
# 1                 163519        122        False      ACTIVE           30.0
# 2                 163519        122        False      ACTIVE           30.0
# 3                 163519        122        False      ACTIVE           30.0
# 4                 163519        122        False      ACTIVE           30.0
#
#   bidding_currency  bidding_value_usd      keyword_variation  request  \
# 0              INR             0.4059             sheet mask  14900.0
# 1              INR             0.4059     garnier sheet mask   1069.0
# 2              INR             0.4059  good vibes sheet mask    657.0
# 3              INR             0.4059       sheet mask combo    624.0
# 4              INR             0.4059  lakme face sheet mask    571.0
#
#   response         RR
# 0  14854.0  99.691275
# 1    406.0   37.97942
# 2    655.0  99.695586
# 3    623.0  99.839744
# 4    214.0  37.478109

# %%
combined_camp_keyword_match_df[combined_camp_keyword_match_df['text']=='bathing powder']
# Out:
#          keyword_id  marketing_campaign_id            text match_type  \
# 8020584     1298356                 790131  bathing powder     PHRASE
# 8020585     1298356                 790131  bathing powder     PHRASE
# 8020586     1298356                 790131  bathing powder     PHRASE
# 8020587     1298356                 790131  bathing powder     PHRASE
# 8020588     1298356                 790131  bathing powder     PHRASE
# 8020589     1298356                 790131  bathing powder     PHRASE
# 8020590     1298356                 790131  bathing powder     PHRASE
# 8020591     1298356                 790131  bathing powder     PHRASE
# 8020592     1298356                 790131  bathing powder     PHRASE
# 8020593     1298356                 790131  bathing powder     PHRASE
# 8020594     1298356                 790131  bathing powder     PHRASE
# 8020595     1298356                 790131  bathing powder     PHRASE
# 8020596     1298356                 790131  bathing powder     PHRASE
# 8020597     1298356                 790131  bathing powder     PHRASE
#
#          marketplace_client_id  agency_id  is_negative status_type  \
# 8020584                 163519        122        False      ACTIVE
# 8020585                 163519        122        False      ACTIVE
# 8020586                 163519        122        False      ACTIVE
# 8020587                 163519        122        False      ACTIVE
# 8020588                 163519        122        False      ACTIVE
# 8020589                 163519        122        False      ACTIVE
# 8020590                 163519        122        False      ACTIVE
# 8020591                 163519        122        False      ACTIVE
# 8020592                 163519        122        False      ACTIVE
# 8020593                 163519        122        False      ACTIVE
# 8020594                 163519        122        False      ACTIVE
# 8020595                 163519        122        False      ACTIVE
# 8020596                 163519        122        False      ACTIVE
# 8020597                 163519        122        False      ACTIVE
#
#          bidding_value bidding_currency  bidding_value_usd  \
# 8020584          18.48              INR             0.2501
# 8020585          18.48              INR             0.2501
# 8020586          18.48              INR             0.2501
# 8020587          18.48              INR             0.2501
# 8020588          18.48              INR             0.2501
# 8020589          18.48              INR             0.2501
# 8020590          18.48              INR             0.2501
# 8020591          18.48              INR             0.2501
# 8020592          18.48              INR             0.2501
# 8020593          18.48              INR             0.2501
# 8020594          18.48              INR             0.2501
# 8020595          18.48              INR             0.2501
# 8020596          18.48              INR             0.2501
# 8020597          18.48              INR             0.2501
#
#                        keyword_variation request response         RR
# 8020584         mamaearth bathing powder     4.0      0.0        0.0
# 8020585        good vibes bathing powder    38.0     34.0  89.473684
# 8020586     alps goodness bathing powder     2.0      2.0      100.0
# 8020587              body bathing powder     2.0      0.0        0.0
# 8020588    bathing powder body whitening     1.0      0.0        0.0
# 8020589                   bathing powder    21.0      0.0        0.0
# 8020590            herbal bathing powder    15.0      2.0  13.333333
# 8020591              baby bathing powder     4.0      0.0        0.0
# 8020592     bathing powder for baby girl     4.0      0.0        0.0
# 8020593  magnum wood girl bathing powder     2.0      0.0        0.0
# 8020594     evevin herbal bathing powder     2.0      0.0        0.0
# 8020595            evevin bathing powder     2.0      0.0        0.0
# 8020596            shubra bathing powder     1.0      0.0        0.0
# 8020597    herbal bathing powder for men     1.0      0.0        0.0

# %%
# shared_camp_key_df = tagged_camp_key_df[['agency_id', 'keyword_id', 'marketing_campaign_id', 'text', 'match_type', 'request', 'response', 'RR', 'reach_tag']]
# shared_camp_key_df.shape
# Out:
# (44974, 9)

# %%
# shared_camp_key_df[shared_camp_key_df['text']=='sunlight']
# Out:
# Empty DataFrame
# Columns: [agency_id, keyword_id, marketing_campaign_id, text, match_type, request, response, RR, reach_tag]
# Index: []

# %%
combined_camp_keyword_match_df = combined_camp_keyword_match_df.drop(['marketplace_client_id', 'agency_id', 'is_negative', 'status_type', 'bidding_value', 'bidding_currency'], axis=1)

# %%
combined_camp_keyword_match_df.to_csv("combined_camp_keyword&variations_df_163519.csv", index=False)

# %% [markdown]
# ### Adding campaigns category and keywords top categories(In the next Notebook)

# %% [raw]
# # Path used to get top categories data
# s3://os-search-relevancy-data/prod/ (keywords in trimmed version)
# # To fetch categories present in campaign we have used one redshift query
